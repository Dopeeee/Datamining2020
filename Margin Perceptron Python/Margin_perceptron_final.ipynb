# %%
import math

# %%
f = open("d5.txt", "r")  # 打开文件
    #data = f.read()  # 读取文件
data_format = f.readline()
num_point = int(data_format[0])
num_dim = int(data_format[2])
w = [0]
# 建造w
for i in range(num_dim-1):
    w.append(0)
#查看数据
print(num_point)
print(num_dim)
print(w)
print(w[0]+1)
print(w)
# Out:
# 1
# 0
# [0]
# 1
# [0]

# %%
# 打开文件
#f_tmp = open("data_point.txt", "r") 
f_tmp = open("d2.txt", "r") 
#f_tmp = open("new_train_d9.txt", "r") 
data_format = f_tmp.readline()
# 读数据格式
data_format = data_format.split(' ')
num_point = int(data_format[0])
num_dim = int(data_format[1])
w = [0]
# 建造w
for i in range(num_dim-1):
    w.append(0)
# 建造空数据集
points_list = []
# 建造数据集
points = f_tmp.readlines()
for i in points:
    points_list.append(i.split())
points_list
# Out:
# [['31', '-47', '0'],
#  ['37', '42', '1'],
#  ['38', '-28', '1'],
#  ['34', '-46', '0'],
#  ['37', '-23', '1'],
#  ['-21', '44', '1'],
#  ['30', '44', '1'],
#  ['-35', '47', '1'],
#  ['-22', '-40', '0'],
#  ['35', '-49', '0'],
#  ['22', '-42', '0'],
#  ['21', '-49', '0'],
#  ['-33', '14', '0'],
#  ['38', '30', '1'],
#  ['-37', '-47', '0'],
#  ['29', '30', '1'],
#  ['-24', '-50', '0'],
#  ['-32', '16', '0'],
#  ['22', '48', '1'],
#  ['-26', '-45', '0'],
#  ['-24', '-33', '0'],
#  ['-36', '21', '0'],
#  ['22', '-43', '0'],
#  ['-39', '19', '0'],
#  ['36', '-20', '1'],
#  ['-30', '-30', '0'],
#  ['-27', '-43', '0'],
#  ['-40', '16', '0'],
#  ['27', '31', '1'],
#  ['20', '38', '1'],
#  ['39', '-16', '1'],
#  ['40', '46', '1'],
#  ['-35', '-42', '0'],
#  ['-31', '-31', '0'],
#  ['24', '-47', '0'],
#  ['-28', '13', '0'],
#  ['-30', '-34', '0'],
#  ['30', '-17', '1'],
#  ['-35', '-50', '0'],
#  ['-24', '-35', '0'],
#  ['30', '42', '1'],
#  ['-27', '39', '1'],
#  ['34', '-13', '1'],
#  ['-32', '-31', '0'],
#  ['24', '-38', '0'],
#  ['-29', '-48', '0'],
#  ['29', '-49', '0'],
#  ['-39', '-30', '0'],
#  ['-20', '-36', '0'],
#  ['26', '47', '1'],
#  ['37', '36', '1'],
#  ['-33', '-43', '0'],
#  ['-22', '-35', '0'],
#  ['-27', '-40', '0'],
#  ['33', '-50', '0'],
#  ['27', '34', '1'],
#  ['30', '-18', '1'],
#  ['-29', '39', '1'],
#  ['25', '-12', '1'],
#  ['22', '-39', '0'],
#  ['-31', '-44', '0'],
#  ['-27', '-46', '0'],
#  ['-25', '-50', '0'],
#  ['-26', '-32', '0'],
#  ['24', '-13', '1'],
#  ['-28', '50', '1'],
#  ['-26', '-30', '0'],
#  ['-30', '46', '1'],
#  ['-30', '13', '0'],
#  ['-38', '-44', '0'],
#  ['23', '-40', '0'],
#  ['-32', '15', '0'],
#  ['-31', '-39', '0'],
#  ['-34', '-45', '0'],
#  ['-27', '-43', '0'],
#  ['-36', '14', '0'],
#  ['-39', '12', '0'],
#  ['37', '-14', '1'],
#  ['35', '-17', '1'],
#  ['28', '-40', '0'],
#  ['24', '44', '1'],
#  ['21', '-40', '0'],
#  ['29', '-46', '0'],
#  ['33', '50', '1'],
#  ['-32', '-35', '0'],
#  ['-32', '-36', '0'],
#  ['38', '32', '1'],
#  ['34', '41', '1'],
#  ['37', '-25', '1'],
#  ['-31', '-48', '0'],
#  ['-22', '39', '1'],
#  ['-26', '-38', '0'],
#  ['-33', '-39', '0'],
#  ['25', '40', '1'],
#  ['39', '-16', '1'],
#  ['37', '-20', '1'],
#  ['37', '-17', '1'],
#  ['-23', '-35', '0'],
#  ['-23', '39', '1'],
#  ['-26', '-45', '0'],
#  ['22', '-11', '1'],
#  ['-21', '-34', '0'],
#  ['32', '46', '1'],
#  ['24', '33', '1'],
#  ['-23', '35', '1'],
#  ['-33', '12', '0'],
#  ['32', '-16', '1'],
#  ['20', '43', '1'],
#  ['-30', '41', '1'],
#  ['-28', '17', '0'],
#  ['38', '38', '1'],
#  ['-26', '44', '1'],
#  ['-40', '15', '0'],
#  ['22', '39', '1'],
#  ['-34', '-48', '0'],
#  ['-31', '-32', '0'],
#  ['39', '-21', '1'],
#  ['30', '-41', '0'],
#  ['31', '-50', '0'],
#  ['-26', '-35', '0'],
#  ['-28', '47', '1'],
#  ['36', '36', '1'],
#  ['-39', '-41', '0'],
#  ['-24', '11', '0'],
#  ['40', '-24', '1'],
#  ['23', '-37', '0'],
#  ['-38', '48', '1'],
#  ['38', '32', '1'],
#  ['-35', '-42', '0'],
#  ['-22', '-49', '0'],
#  ['-26', '14', '0'],
#  ['-21', '38', '1'],
#  ['38', '-27', '1'],
#  ['-36', '16', '0'],
#  ['29', '42', '1'],
#  ['-31', '-36', '0'],
#  ['34', '-23', '1'],
#  ['29', '43', '1'],
#  ['-35', '-40', '0'],
#  ['-40', '-34', '0'],
#  ['25', '40', '1'],
#  ['-30', '45', '1'],
#  ['-32', '10', '0'],
#  ['27', '-15', '1'],
#  ['-24', '-49', '0'],
#  ['-37', '-50', '0'],
#  ['36', '-47', '0'],
#  ['31', '-42', '0'],
#  ['-38', '-33', '0'],
#  ['40', '34', '1'],
#  ['34', '49', '1'],
#  ['-30', '-46', '0'],
#  ['23', '47', '1'],
#  ['-33', '-41', '0'],
#  ['-35', '46', '1'],
#  ['-21', '-48', '0'],
#  ['-38', '14', '0'],
#  ['-21', '40', '1'],
#  ['-34', '-47', '0'],
#  ['23', '-44', '0'],
#  ['40', '-16', '1'],
#  ['-36', '-46', '0'],
#  ['-21', '-33', '0'],
#  ['25', '44', '1'],
#  ['-37', '24', '0'],
#  ['-38', '23', '0'],
#  ['-32', '-50', '0'],
#  ['-23', '43', '1'],
#  ['-28', '13', '0'],
#  ['-25', '43', '1'],
#  ['-39', '-37', '0'],
#  ['39', '-25', '1'],
#  ['-26', '-37', '0'],
#  ['-28', '44', '1'],
#  ['-26', '-49', '0'],
#  ['-31', '18', '0'],
#  ['36', '50', '1'],
#  ['-20', '37', '1'],
#  ['27', '-13', '1'],
#  ['-30', '-49', '0'],
#  ['-33', '11', '0'],
#  ['26', '-40', '0'],
#  ['33', '-46', '0'],
#  ['37', '46', '1'],
#  ['20', '-35', '0'],
#  ['31', '45', '1'],
#  ['-40', '50', '1'],
#  ['24', '-38', '0'],
#  ['-25', '-36', '0'],
#  ['-40', '10', '0'],
#  ['26', '47', '1'],
#  ['31', '-16', '1'],
#  ['29', '35', '1'],
#  ['22', '-40', '0'],
#  ['-24', '40', '1'],
#  ['-25', '45', '1'],
#  ['23', '-41', '0'],
#  ['40', '40', '1'],
#  ['40', '-28', '1'],
#  ['21', '-42', '0'],
#  ['-35', '-35', '0'],
#  ['29', '-13', '1'],
#  ['-35', '45', '1'],
#  ['-25', '-35', '0'],
#  ['32', '49', '1'],
#  ['-40', '22', '0'],
#  ['-29', '48', '1'],
#  ['-36', '-39', '0'],
#  ['-37', '-31', '0'],
#  ['-32', '-34', '0'],
#  ['40', '-18', '1'],
#  ['26', '-49', '0'],
#  ['23', '50', '1'],
#  ['-36', '-32', '0'],
#  ['-40', '-42', '0'],
#  ['-39', '-45', '0'],
#  ['-20', '46', '1'],
#  ['27', '43', '1'],
#  ['-35', '14', '0'],
#  ['36', '-50', '0'],
#  ['29', '-50', '0'],
#  ['-20', '36', '1'],
#  ['-31', '15', '0'],
#  ['-21', '42', '1'],
#  ['36', '45', '1'],
#  ['30', '-11', '1'],
#  ['21', '-36', '0'],
#  ['-39', '-44', '0'],
#  ['33', '34', '1'],
#  ['38', '-15', '1'],
#  ['22', '-38', '0'],
#  ['28', '-11', '1'],
#  ['27', '44', '1'],
#  ['-32', '-47', '0'],
#  ['-40', '-40', '0'],
#  ['38', '-28', '1'],
#  ['-20', '47', '1'],
#  ['34', '-19', '1'],
#  ['28', '-40', '0'],
#  ['20', '-34', '0'],
#  ['-39', '-36', '0'],
#  ['-23', '36', '1'],
#  ['27', '-16', '1'],
#  ['32', '36', '1'],
#  ['-36', '-32', '0'],
#  ['-22', '43', '1'],
#  ['-30', '-39', '0'],
#  ['-32', '16', '0'],
#  ['24', '36', '1'],
#  ['-25', '44', '1'],
#  ['36', '-13', '1'],
#  ['23', '-43', '0'],
#  ['29', '31', '1'],
#  ['-21', '10', '0'],
#  ['32', '47', '1'],
#  ['21', '-10', '1'],
#  ['29', '40', '1'],
#  ['-25', '-30', '0'],
#  ['30', '31', '1'],
#  ['36', '45', '1'],
#  ['-28', '40', '1'],
#  ['35', '-48', '0'],
#  ['35', '43', '1'],
#  ['29', '-44', '0'],
#  ['-36', '-35', '0'],
#  ['37', '-13', '1'],
#  ['30', '-45', '0'],
#  ['-27', '16', '0'],
#  ['-37', '-30', '0'],
#  ['-34', '-30', '0'],
#  ['21', '42', '1'],
#  ['39', '-26', '1'],
#  ['-20', '40', '1'],
#  ['-39', '-31', '0'],
#  ['40', '43', '1'],
#  ['-36', '-49', '0'],
#  ['33', '-49', '0'],
#  ['-31', '-31', '0'],
#  ['25', '49', '1'],
#  ['34', '34', '1'],
#  ['28', '-39', '0'],
#  ['27', '34', '1'],
#  ['-25', '-34', '0'],
#  ['-29', '-47', '0'],
#  ['-38', '14', '0'],
#  ['-32', '16', '0'],
#  ['-32', '44', '1'],
#  ['-32', '45', '1'],
#  ['39', '-26', '1'],
#  ['36', '-10', '1'],
#  ['-21', '37', '1'],
#  ['-20', '-38', '0'],
#  ['22', '-47', '0'],
#  ['29', '-41', '0'],
#  ['-32', '-30', '0'],
#  ['28', '-15', '1'],
#  ['-23', '-31', '0'],
#  ['32', '50', '1'],
#  ['26', '-49', '0'],
#  ['25', '-38', '0'],
#  ['29', '47', '1'],
#  ['30', '-18', '1'],
#  ['30', '42', '1'],
#  ['26', '-13', '1'],
#  ['-31', '15', '0'],
#  ['-23', '-42', '0'],
#  ['-34', '47', '1'],
#  ['-29', '-44', '0'],
#  ['35', '41', '1'],
#  ['-32', '12', '0'],
#  ['30', '-15', '1'],
#  ['31', '-21', '1'],
#  ['-26', '-34', '0'],
#  ['-36', '23', '0'],
#  ['-35', '-50', '0'],
#  ['-25', '48', '1'],
#  ['31', '31', '1'],
#  ['-33', '19', '0'],
#  ['-40', '11', '0'],
#  ['-34', '16', '0'],
#  ['21', '-47', '0'],
#  ['-39', '-37', '0'],
#  ['36', '37', '1'],
#  ['-24', '-31', '0'],
#  ['40', '48', '1'],
#  ['-32', '49', '1'],
#  ['-30', '40', '1'],
#  ['-35', '19', '0'],
#  ['36', '35', '1'],
#  ['-40', '-37', '0'],
#  ['25', '38', '1'],
#  ['32', '-19', '1'],
#  ['-23', '41', '1'],
#  ['-21', '-36', '0'],
#  ['-32', '-31', '0'],
#  ['23', '-39', '0'],
#  ['25', '-11', '1'],
#  ['-25', '45', '1'],
#  ['-27', '37', '1'],
#  ['40', '-23', '1'],
#  ['-33', '-32', '0'],
#  ['-39', '12', '0'],
#  ['-39', '15', '0'],
#  ['-37', '-40', '0'],
#  ['-28', '17', '0'],
#  ['25', '-40', '0'],
#  ['-36', '-44', '0'],
#  ['40', '-30', '1'],
#  ['-20', '-46', '0'],
#  ['-24', '-41', '0'],
#  ['-39', '18', '0'],
#  ['-31', '13', '0'],
#  ['-30', '42', '1'],
#  ['-21', '-39', '0'],
#  ['-36', '21', '0'],
#  ['-39', '-36', '0'],
#  ['36', '48', '1'],
#  ['-20', '-30', '0'],
#  ['-40', '-30', '0'],
#  ['25', '-12', '1'],
#  ['28', '-17', '1'],
#  ['28', '49', '1'],
#  ['-32', '-45', '0'],
#  ['38', '-21', '1'],
#  ['-31', '-44', '0'],
#  ['20', '31', '1'],
#  ['-38', '-41', '0'],
#  ['-29', '-46', '0'],
#  ['-27', '-49', '0'],
#  ['29', '45', '1'],
#  ['-38', '-34', '0'],
#  ['-26', '48', '1'],
#  ['32', '-10', '1'],
#  ['33', '-20', '1'],
#  ['-34', '13', '0'],
#  ['35', '37', '1'],
#  ['-32', '-43', '0'],
#  ['39', '48', '1'],
#  ['20', '46', '1'],
#  ['23', '-46', '0'],
#  ['-24', '-48', '0'],
#  ['-22', '49', '1'],
#  ['27', '35', '1'],
#  ['-35', '46', '1'],
#  ['36', '36', '1'],
#  ['-22', '-46', '0'],
#  ['-34', '50', '1'],
#  ['-22', '-47', '0'],
#  ['-27', '45', '1'],
#  ['-23', '-34', '0'],
#  ['38', '-17', '1'],
#  ['-31', '-30', '0'],
#  ['27', '-14', '1'],
#  ['-23', '-41', '0'],
#  ['-24', '50', '1'],
#  ['-39', '12', '0'],
#  ['-21', '-48', '0'],
#  ['32', '30', '1'],
#  ['-34', '14', '0'],
#  ['-37', '10', '0'],
#  ['33', '48', '1'],
#  ['31', '36', '1'],
#  ['-36', '14', '0'],
#  ['32', '-45', '0'],
#  ['-20', '-41', '0'],
#  ['32', '-10', '1'],
#  ['28', '-10', '1'],
#  ['-39', '18', '0'],
#  ['24', '41', '1'],
#  ['37', '-25', '1'],
#  ['39', '-17', '1'],
#  ['-33', '14', '0'],
#  ['33', '-15', '1'],
#  ['37', '38', '1'],
#  ['30', '-44', '0'],
#  ['-30', '-40', '0'],
#  ['-39', '25', '0'],
#  ['-32', '47', '1'],
#  ['-33', '15', '0'],
#  ['-34', '-43', '0'],
#  ['-39', '-35', '0'],
#  ['-27', '-34', '0'],
#  ['34', '32', '1'],
#  ['20', '43', '1'],
#  ['-34', '-42', '0'],
#  ['33', '42', '1'],
#  ['-21', '36', '1'],
#  ['30', '42', '1'],
#  ['-20', '-45', '0'],
#  ['39', '-27', '1'],
#  ['34', '38', '1'],
#  ['28', '43', '1'],
#  ['25', '-39', '0'],
#  ['-21', '34', '1'],
#  ['-26', '12', '0'],
#  ['26', '-12', '1'],
#  ['-39', '24', '0'],
#  ['40', '30', '1'],
#  ['29', '-19', '1'],
#  ['-27', '-42', '0'],
#  ['30', '40', '1'],
#  ['-37', '-43', '0'],
#  ['-21', '42', '1'],
#  ['-31', '-47', '0'],
#  ['-37', '-30', '0'],
#  ['-40', '-45', '0'],
#  ['-25', '-49', '0'],
#  ['-22', '32', '1'],
#  ['-27', '-43', '0'],
#  ['-30', '-43', '0'],
#  ['-22', '48', '1'],
#  ['-33', '-38', '0'],
#  ['36', '39', '1'],
#  ['-27', '-43', '0'],
#  ['37', '-13', '1'],
#  ['-24', '46', '1'],
#  ['-39', '-50', '0'],
#  ['30', '48', '1'],
#  ['-27', '-41', '0'],
#  ['-22', '37', '1'],
#  ['-33', '-42', '0'],
#  ['23', '-45', '0'],
#  ['-27', '13', '0'],
#  ['-26', '-39', '0'],
#  ['40', '-12', '1'],
#  ['37', '43', '1'],
#  ['26', '-11', '1'],
#  ['36', '-13', '1'],
#  ['-33', '-49', '0'],
#  ['-20', '50', '1'],
#  ['28', '31', '1'],
#  ['-35', '19', '0'],
#  ['-39', '49', '1'],
#  ['-20', '40', '1'],
#  ['-33', '14', '0'],
#  ['-25', '41', '1'],
#  ['-24', '-46', '0'],
#  ['40', '35', '1'],
#  ['-32', '12', '0'],
#  ['25', '-11', '1'],
#  ['-22', '-36', '0'],
#  ['-29', '12', '0'],
#  ['-28', '-49', '0'],
#  ['36', '-16', '1'],
#  ['-38', '12', '0'],
#  ['36', '-49', '0'],
#  ['20', '38', '1'],
#  ['29', '44', '1'],
#  ['-32', '-46', '0'],
#  ['35', '-19', '1'],
#  ['-32', '48', '1'],
#  ['-35', '-38', '0'],
#  ['23', '42', '1'],
#  ['-29', '44', '1'],
#  ['-22', '-46', '0'],
#  ['-36', '-34', '0'],
#  ['32', '-45', '0'],
#  ['34', '-23', '1'],
#  ['21', '-35', '0'],
#  ['-24', '-32', '0'],
#  ['21', '-41', '0'],
#  ['-34', '17', '0'],
#  ['-27', '48', '1'],
#  ['-34', '-43', '0'],
#  ['35', '44', '1'],
#  ['-35', '20', '0'],
#  ['-38', '-46', '0'],
#  ['-35', '-40', '0'],
#  ['40', '-16', '1'],
#  ['39', '33', '1'],
#  ['-20', '-32', '0'],
#  ['28', '-14', '1'],
#  ['-27', '46', '1'],
#  ['31', '-44', '0'],
#  ['-36', '-41', '0'],
#  ['24', '-37', '0'],
#  ['40', '-23', '1'],
#  ['28', '34', '1'],
#  ['-40', '-32', '0'],
#  ['30', '-14', '1'],
#  ['-21', '32', '1'],
#  ['39', '50', '1'],
#  ['-22', '-48', '0'],
#  ['31', '-20', '1'],
#  ['-32', '42', '1'],
#  ['-38', '24', '0'],
#  ['24', '32', '1'],
#  ['-22', '45', '1'],
#  ['-20', '-33', '0'],
#  ['-25', '-40', '0'],
#  ['35', '31', '1'],
#  ['-22', '45', '1'],
#  ['-23', '-47', '0'],
#  ['24', '48', '1'],
#  ['-24', '-36', '0'],
#  ['-36', '-30', '0'],
#  ['35', '-20', '1'],
#  ['-36', '15', '0'],
#  ['-26', '41', '1'],
#  ['-32', '14', '0'],
#  ['-20', '44', '1'],
#  ['25', '-46', '0'],
#  ['39', '42', '1'],
#  ['-25', '-36', '0'],
#  ['39', '-24', '1'],
#  ['33', '35', '1'],
#  ['-34', '12', '0'],
#  ['24', '-40', '0'],
#  ['35', '32', '1'],
#  ['-26', '-35', '0'],
#  ['22', '-12', '1'],
#  ['39', '49', '1'],
#  ['-22', '39', '1'],
#  ['-32', '50', '1'],
#  ['31', '-48', '0'],
#  ['32', '-49', '0'],
#  ['36', '36', '1'],
#  ['-23', '-39', '0'],
#  ['-39', '-42', '0'],
#  ['-27', '11', '0'],
#  ['-36', '-39', '0'],
#  ['-22', '-43', '0'],
#  ['28', '41', '1'],
#  ['-35', '-48', '0'],
#  ['-23', '-50', '0'],
#  ['21', '-47', '0'],
#  ['26', '-47', '0'],
#  ['-35', '-47', '0'],
#  ['-20', '-39', '0'],
#  ['33', '-46', '0'],
#  ['-24', '-32', '0'],
#  ['34', '-23', '1'],
#  ['36', '-10', '1'],
#  ['31', '39', '1'],
#  ['-38', '25', '0'],
#  ['39', '34', '1'],
#  ['23', '-48', '0'],
#  ['24', '-49', '0'],
#  ['40', '41', '1'],
#  ['34', '-14', '1'],
#  ['34', '49', '1'],
#  ['-27', '45', '1'],
#  ['27', '37', '1'],
#  ['26', '-48', '0'],
#  ['24', '34', '1'],
#  ['20', '-48', '0'],
#  ['-23', '40', '1'],
#  ['-33', '-36', '0'],
#  ['-30', '-50', '0'],
#  ['-39', '23', '0'],
#  ['-34', '-46', '0'],
#  ['-22', '38', '1'],
#  ['35', '-16', '1'],
#  ['-23', '-49', '0'],
#  ['28', '42', '1'],
#  ['-32', '-32', '0'],
#  ['-33', '43', '1'],
#  ['-34', '-40', '0'],
#  ['-31', '-46', '0'],
#  ['-31', '-44', '0'],
#  ['-21', '-31', '0'],
#  ['-30', '18', '0'],
#  ['27', '36', '1'],
#  ['-20', '-36', '0'],
#  ['24', '33', '1'],
#  ['-22', '40', '1'],
#  ['28', '50', '1'],
#  ['36', '-26', '1'],
#  ['-20', '-39', '0'],
#  ['36', '42', '1'],
#  ['-25', '-39', '0'],
#  ['-24', '-36', '0'],
#  ['31', '-43', '0'],
#  ['-27', '-41', '0'],
#  ['33', '-44', '0'],
#  ['-37', '-33', '0'],
#  ['30', '-11', '1'],
#  ['-22', '-42', '0'],
#  ['25', '45', '1'],
#  ['31', '-18', '1'],
#  ['38', '-25', '1'],
#  ['-31', '-30', '0'],
#  ['34', '-15', '1'],
#  ['-37', '10', '0'],
#  ['34', '50', '1'],
#  ['35', '40', '1'],
#  ['-21', '-48', '0'],
#  ['20', '-49', '0'],
#  ['27', '46', '1'],
#  ['35', '45', '1'],
#  ['25', '42', '1'],
#  ['37', '-17', '1'],
#  ['-38', '-32', '0'],
#  ['30', '-43', '0'],
#  ['-35', '-39', '0'],
#  ['26', '34', '1'],
#  ['-21', '-33', '0'],
#  ['30', '-50', '0'],
#  ['-30', '-40', '0'],
#  ['31', '-17', '1'],
#  ['-24', '13', '0'],
#  ['35', '-22', '1'],
#  ['25', '40', '1'],
#  ['-39', '26', '0'],
#  ['34', '44', '1'],
#  ['39', '-28', '1'],
#  ['29', '34', '1'],
#  ['-33', '-45', '0'],
#  ['-23', '-38', '0'],
#  ['-33', '-35', '0'],
#  ['-22', '40', '1'],
#  ['-25', '-32', '0'],
#  ['-38', '-36', '0'],
#  ['35', '46', '1'],
#  ['40', '42', '1'],
#  ['34', '49', '1'],
#  ['30', '49', '1'],
#  ['-32', '14', '0'],
#  ['40', '36', '1'],
#  ['23', '-42', '0'],
#  ['31', '-47', '0'],
#  ['38', '-27', '1'],
#  ['-35', '12', '0'],
#  ['40', '-19', '1'],
#  ['-27', '-44', '0'],
#  ['-28', '50', '1'],
#  ['-23', '-33', '0'],
#  ['-27', '-42', '0'],
#  ['27', '-16', '1'],
#  ['-20', '45', '1'],
#  ['-29', '-35', '0'],
#  ['23', '48', '1'],
#  ['25', '-43', '0'],
#  ['27', '33', '1'],
#  ['-23', '12', '0'],
#  ['-36', '-45', '0'],
#  ['37', '44', '1'],
#  ['-34', '23', '0'],
#  ['-30', '-36', '0'],
#  ['-24', '-41', '0'],
#  ['36', '39', '1'],
#  ['39', '43', '1'],
#  ['35', '-22', '1'],
#  ['38', '-17', '1'],
#  ['28', '50', '1'],
#  ['-33', '-50', '0'],
#  ['-21', '-43', '0'],
#  ['24', '31', '1'],
#  ['28', '-12', '1'],
#  ['35', '50', '1'],
#  ['-34', '-39', '0'],
#  ['23', '40', '1'],
#  ['34', '-22', '1'],
#  ['23', '-37', '0'],
#  ['32', '37', '1'],
#  ['-30', '-36', '0'],
#  ['33', '30', '1'],
#  ['-37', '13', '0'],
#  ['35', '30', '1'],
#  ['27', '-39', '0'],
#  ['-32', '-41', '0'],
#  ['34', '-11', '1'],
#  ['-21', '-37', '0'],
#  ['-29', '43', '1'],
#  ['30', '46', '1'],
#  ['-30', '-40', '0'],
#  ['-37', '-37', '0'],
#  ['-31', '20', '0'],
#  ['-28', '-32', '0'],
#  ['-29', '-43', '0'],
#  ['39', '-50', '0'],
#  ['23', '38', '1'],
#  ['-36', '10', '0'],
#  ['-24', '45', '1'],
#  ['-27', '-43', '0'],
#  ['-39', '11', '0'],
#  ['23', '41', '1'],
#  ['-37', '25', '0'],
#  ['-33', '-30', '0'],
#  ['27', '41', '1'],
#  ['-23', '-34', '0'],
#  ['-21', '-45', '0'],
#  ['30', '-45', '0'],
#  ['28', '-40', '0'],
#  ['-23', '50', '1'],
#  ['-36', '50', '1'],
#  ['-36', '10', '0'],
#  ['37', '-25', '1'],
#  ['-22', '-33', '0'],
#  ['35', '-11', '1'],
#  ['-29', '-37', '0'],
#  ['29', '-50', '0'],
#  ['-39', '-32', '0'],
#  ['24', '-12', '1'],
#  ['-32', '44', '1'],
#  ['29', '-12', '1'],
#  ['38', '35', '1'],
#  ['-22', '-40', '0'],
#  ['22', '42', '1'],
#  ['-37', '-39', '0'],
#  ['30', '-10', '1'],
#  ['-25', '11', '0'],
#  ['-20', '-41', '0'],
#  ['32', '42', '1'],
#  ['-20', '-44', '0'],
#  ['-27', '42', '1'],
#  ['-35', '-40', '0'],
#  ['-27', '49', '1'],
#  ['-30', '48', '1'],
#  ['22', '40', '1'],
#  ['21', '-41', '0'],
#  ['33', '50', '1'],
#  ['35', '31', '1'],
#  ['28', '-15', '1'],
#  ['-29', '-48', '0'],
#  ['-28', '45', '1'],
#  ['39', '-27', '1'],
#  ['-25', '-30', '0'],
#  ['36', '32', '1'],
#  ['26', '-49', '0'],
#  ['21', '35', '1'],
#  ['34', '-20', '1'],
#  ['-23', '-49', '0'],
#  ['-39', '25', '0'],
#  ['-22', '10', '0'],
#  ['20', '37', '1'],
#  ['33', '-44', '0'],
#  ['-40', '21', '0'],
#  ['-28', '-47', '0'],
#  ['22', '32', '1'],
#  ['-35', '23', '0'],
#  ['37', '39', '1'],
#  ['34', '50', '1'],
#  ['-22', '37', '1'],
#  ['-22', '-40', '0'],
#  ['30', '-47', '0'],
#  ['-38', '13', '0'],
#  ['-25', '-38', '0'],
#  ['-30', '19', '0'],
#  ['33', '33', '1'],
#  ['-28', '-36', '0'],
#  ['39', '-17', '1'],
#  ['28', '-13', '1'],
#  ['-27', '38', '1'],
#  ['34', '-19', '1'],
#  ['-39', '18', '0'],
#  ['-39', '-40', '0'],
#  ['-22', '-31', '0'],
#  ['25', '44', '1'],
#  ['26', '-49', '0'],
#  ['-36', '-45', '0'],
#  ['-31', '11', '0'],
#  ['-21', '31', '1'],
#  ['-25', '-45', '0'],
#  ['-28', '48', '1'],
#  ['-24', '50', '1'],
#  ['-34', '13', '0'],
#  ['31', '-18', '1'],
#  ['30', '40', '1'],
#  ['-39', '20', '0'],
#  ['-40', '11', '0'],
#  ['-27', '-34', '0'],
#  ['22', '-40', '0'],
#  ['22', '-42', '0'],
#  ['23', '38', '1'],
#  ['-31', '16', '0'],
#  ['39', '-24', '1'],
#  ['26', '-47', '0'],
#  ['-39', '20', '0'],
#  ['-38', '-31', '0'],
#  ['-36', '49', '1'],
#  ['31', '45', '1'],
#  ['39', '50', '1'],
#  ['-29', '-36', '0'],
#  ['-34', '-37', '0'],
#  ['31', '-14', '1'],
#  ['-22', '-48', '0'],
#  ['-23', '-48', '0'],
#  ['-26', '-41', '0'],
#  ['-31', '19', '0'],
#  ['26', '40', '1'],
#  ['-25', '41', '1'],
#  ['-20', '38', '1'],
#  ['-38', '50', '1'],
#  ['-37', '-50', '0'],
#  ['-40', '11', '0'],
#  ['-40', '13', '0'],
#  ['-30', '17', '0'],
#  ['33', '49', '1'],
#  ['-28', '-37', '0'],
#  ['30', '-44', '0'],
#  ['26', '35', '1'],
#  ['39', '-24', '1'],
#  ['-38', '21', '0'],
#  ['40', '45', '1'],
#  ['30', '-20', '1'],
#  ['-37', '18', '0'],
#  ['38', '-11', '1'],
#  ['26', '50', '1'],
#  ['-22', '-45', '0'],
#  ['26', '36', '1'],
#  ['-39', '16', '0'],
#  ['27', '-46', '0'],
#  ['-22', '-44', '0'],
#  ['-39', '-40', '0'],
#  ['27', '46', '1'],
#  ['29', '40', '1'],
#  ['25', '-13', '1'],
#  ['24', '34', '1'],
#  ['39', '-15', '1'],
#  ['-29', '18', '0'],
#  ['-22', '32', '1'],
#  ['40', '45', '1'],
#  ['39', '-21', '1'],
#  ['24', '-40', '0'],
#  ['-32', '49', '1'],
#  ['35', '-15', '1'],
#  ['34', '33', '1'],
#  ['-22', '41', '1'],
#  ['32', '46', '1'],
#  ['25', '-43', '0'],
#  ['25', '-42', '0'],
#  ['40', '-15', '1'],
#  ['-35', '50', '1'],
#  ['-24', '-41', '0'],
#  ['-22', '-30', '0'],
#  ['-27', '-35', '0'],
#  ['-39', '21', '0'],
#  ['-32', '-35', '0'],
#  ['-20', '-32', '0'],
#  ['32', '-22', '1'],
#  ['-36', '49', '1'],
#  ['-36', '-47', '0'],
#  ['-35', '-48', '0'],
#  ['-23', '37', '1'],
#  ['35', '47', '1'],
#  ['35', '36', '1'],
#  ['20', '-41', '0'],
#  ['34', '-12', '1'],
#  ['38', '-21', '1'],
#  ['-26', '-42', '0'],
#  ['22', '-47', '0'],
#  ['-32', '-38', '0'],
#  ['27', '-43', '0'],
#  ['22', '32', '1'],
#  ['23', '46', '1'],
#  ['-34', '-43', '0'],
#  ['-35', '-46', '0'],
#  ['-38', '15', '0'],
#  ['-39', '25', '0'],
#  ['-40', '-35', '0'],
#  ['-35', '16', '0'],
#  ['-30', '-30', '0'],
#  ['28', '36', '1'],
#  ['-27', '49', '1'],
#  ['-34', '-32', '0'],
#  ['-30', '41', '1'],
#  ['-32', '20', '0'],
#  ['39', '-10', '1'],
#  ['21', '-41', '0'],
#  ['22', '-33', '0'],
#  ['20', '50', '1'],
#  ['33', '50', '1'],
#  ['21', '-32', '0'],
#  ['35', '41', '1'],
#  ['31', '-16', '1'],
#  ['-21', '-47', '0'],
#  ['-29', '16', '0'],
#  ['-38', '-47', '0'],
#  ['33', '41', '1'],
#  ['27', '32', '1'],
#  ['-33', '-50', '0'],
#  ['-21', '-40', '0'],
#  ['29', '31', '1'],
#  ['-40', '-37', '0'],
#  ['23', '32', '1'],
#  ['-40', '-34', '0'],
#  ['-28', '-40', '0'],
#  ['22', '32', '1'],
#  ['-20', '31', '1'],
#  ['35', '45', '1'],
#  ['20', '-42', '0'],
#  ['30', '-49', '0'],
#  ['36', '31', '1'],
#  ['-26', '12', '0'],
#  ['37', '30', '1'],
#  ['-37', '21', '0'],
#  ['-29', '15', '0'],
#  ['33', '-23', '1'],
#  ['-27', '-43', '0'],
#  ['24', '44', '1'],
#  ['-31', '46', '1'],
#  ['-22', '46', '1'],
#  ['-40', '-48', '0'],
#  ['-25', '-33', '0'],
#  ['-34', '-35', '0'],
#  ['38', '36', '1'],
#  ['-40', '-41', '0'],
#  ['-32', '-44', '0'],
#  ['-33', '47', '1'],
#  ['24', '-36', '0'],
#  ['-31', '14', '0'],
#  ['-24', '-33', '0'],
#  ['-33', '-36', '0'],
#  ['-37', '18', '0'],
#  ['28', '-43', '0'],
#  ['26', '-14', '1'],
#  ['-35', '46', '1'],
#  ['-26', '-38', '0'],
#  ['28', '-17', '1'],
#  ['-24', '37', '1'],
#  ['28', '39', '1'],
#  ['-27', '-33', '0'],
#  ['-30', '-45', '0'],
#  ['-21', '47', '1'],
#  ['24', '34', '1'],
#  ['28', '48', '1'],
#  ['-31', '46', '1'],
#  ['28', '-11', '1'],
#  ['21', '-45', '0'],
#  ['29', '41', '1'],
#  ['-30', '-43', '0'],
#  ['24', '-37', '0'],
#  ['-21', '-34', '0'],
#  ['-29', '17', '0'],
#  ['-26', '10', '0'],
#  ['35', '-25', '1'],
#  ['40', '-29', '1'],
#  ['-32', '10', '0'],
#  ['31', '-18', '1'],
#  ['30', '-45', '0'],
#  ['-27', '14', '0'],
#  ['-21', '-44', '0'],
#  ['36', '49', '1'],
#  ['21', '-47', '0'],
#  ['-23', '36', '1'],
#  ['-32', '-33', '0'],
#  ['-32', '-49', '0'],
#  ['-24', '49', '1'],
#  ['-28', '49', '1'],
#  ['35', '42', '1'],
#  ['-39', '22', '0'],
#  ['29', '-15', '1'],
#  ['-26', '50', '1'],
#  ['39', '-29', '1'],
#  ['24', '-37', '0'],
#  ['-39', '13', '0'],
#  ['32', '-45', '0'],
#  ['28', '37', '1'],
#  ['-35', '-46', '0'],
#  ['-38', '-41', '0'],
#  ['26', '42', '1'],
#  ['-29', '-48', '0'],
#  ['22', '-38', '0'],
#  ['25', '-46', '0'],
#  ['-25', '46', '1'],
#  ['-20', '49', '1'],
#  ['34', '-17', '1'],
#  ['-26', '15', '0'],
#  ['27', '-42', '0'],
#  ...]

# %%
num_point,num_dim
# Out:
# (10000, 2)

# %%
def list_str_to_int(points_list):
    for i in range(len(points_list)):
        for j in range(len(points_list[0])):
            points_list[i][j] = int(points_list[i][j])

# %%
list_str_to_int(points_list)
points_list
# Out:
# [[31, -47, 0],
#  [37, 42, 1],
#  [38, -28, 1],
#  [34, -46, 0],
#  [37, -23, 1],
#  [-21, 44, 1],
#  [30, 44, 1],
#  [-35, 47, 1],
#  [-22, -40, 0],
#  [35, -49, 0],
#  [22, -42, 0],
#  [21, -49, 0],
#  [-33, 14, 0],
#  [38, 30, 1],
#  [-37, -47, 0],
#  [29, 30, 1],
#  [-24, -50, 0],
#  [-32, 16, 0],
#  [22, 48, 1],
#  [-26, -45, 0],
#  [-24, -33, 0],
#  [-36, 21, 0],
#  [22, -43, 0],
#  [-39, 19, 0],
#  [36, -20, 1],
#  [-30, -30, 0],
#  [-27, -43, 0],
#  [-40, 16, 0],
#  [27, 31, 1],
#  [20, 38, 1],
#  [39, -16, 1],
#  [40, 46, 1],
#  [-35, -42, 0],
#  [-31, -31, 0],
#  [24, -47, 0],
#  [-28, 13, 0],
#  [-30, -34, 0],
#  [30, -17, 1],
#  [-35, -50, 0],
#  [-24, -35, 0],
#  [30, 42, 1],
#  [-27, 39, 1],
#  [34, -13, 1],
#  [-32, -31, 0],
#  [24, -38, 0],
#  [-29, -48, 0],
#  [29, -49, 0],
#  [-39, -30, 0],
#  [-20, -36, 0],
#  [26, 47, 1],
#  [37, 36, 1],
#  [-33, -43, 0],
#  [-22, -35, 0],
#  [-27, -40, 0],
#  [33, -50, 0],
#  [27, 34, 1],
#  [30, -18, 1],
#  [-29, 39, 1],
#  [25, -12, 1],
#  [22, -39, 0],
#  [-31, -44, 0],
#  [-27, -46, 0],
#  [-25, -50, 0],
#  [-26, -32, 0],
#  [24, -13, 1],
#  [-28, 50, 1],
#  [-26, -30, 0],
#  [-30, 46, 1],
#  [-30, 13, 0],
#  [-38, -44, 0],
#  [23, -40, 0],
#  [-32, 15, 0],
#  [-31, -39, 0],
#  [-34, -45, 0],
#  [-27, -43, 0],
#  [-36, 14, 0],
#  [-39, 12, 0],
#  [37, -14, 1],
#  [35, -17, 1],
#  [28, -40, 0],
#  [24, 44, 1],
#  [21, -40, 0],
#  [29, -46, 0],
#  [33, 50, 1],
#  [-32, -35, 0],
#  [-32, -36, 0],
#  [38, 32, 1],
#  [34, 41, 1],
#  [37, -25, 1],
#  [-31, -48, 0],
#  [-22, 39, 1],
#  [-26, -38, 0],
#  [-33, -39, 0],
#  [25, 40, 1],
#  [39, -16, 1],
#  [37, -20, 1],
#  [37, -17, 1],
#  [-23, -35, 0],
#  [-23, 39, 1],
#  [-26, -45, 0],
#  [22, -11, 1],
#  [-21, -34, 0],
#  [32, 46, 1],
#  [24, 33, 1],
#  [-23, 35, 1],
#  [-33, 12, 0],
#  [32, -16, 1],
#  [20, 43, 1],
#  [-30, 41, 1],
#  [-28, 17, 0],
#  [38, 38, 1],
#  [-26, 44, 1],
#  [-40, 15, 0],
#  [22, 39, 1],
#  [-34, -48, 0],
#  [-31, -32, 0],
#  [39, -21, 1],
#  [30, -41, 0],
#  [31, -50, 0],
#  [-26, -35, 0],
#  [-28, 47, 1],
#  [36, 36, 1],
#  [-39, -41, 0],
#  [-24, 11, 0],
#  [40, -24, 1],
#  [23, -37, 0],
#  [-38, 48, 1],
#  [38, 32, 1],
#  [-35, -42, 0],
#  [-22, -49, 0],
#  [-26, 14, 0],
#  [-21, 38, 1],
#  [38, -27, 1],
#  [-36, 16, 0],
#  [29, 42, 1],
#  [-31, -36, 0],
#  [34, -23, 1],
#  [29, 43, 1],
#  [-35, -40, 0],
#  [-40, -34, 0],
#  [25, 40, 1],
#  [-30, 45, 1],
#  [-32, 10, 0],
#  [27, -15, 1],
#  [-24, -49, 0],
#  [-37, -50, 0],
#  [36, -47, 0],
#  [31, -42, 0],
#  [-38, -33, 0],
#  [40, 34, 1],
#  [34, 49, 1],
#  [-30, -46, 0],
#  [23, 47, 1],
#  [-33, -41, 0],
#  [-35, 46, 1],
#  [-21, -48, 0],
#  [-38, 14, 0],
#  [-21, 40, 1],
#  [-34, -47, 0],
#  [23, -44, 0],
#  [40, -16, 1],
#  [-36, -46, 0],
#  [-21, -33, 0],
#  [25, 44, 1],
#  [-37, 24, 0],
#  [-38, 23, 0],
#  [-32, -50, 0],
#  [-23, 43, 1],
#  [-28, 13, 0],
#  [-25, 43, 1],
#  [-39, -37, 0],
#  [39, -25, 1],
#  [-26, -37, 0],
#  [-28, 44, 1],
#  [-26, -49, 0],
#  [-31, 18, 0],
#  [36, 50, 1],
#  [-20, 37, 1],
#  [27, -13, 1],
#  [-30, -49, 0],
#  [-33, 11, 0],
#  [26, -40, 0],
#  [33, -46, 0],
#  [37, 46, 1],
#  [20, -35, 0],
#  [31, 45, 1],
#  [-40, 50, 1],
#  [24, -38, 0],
#  [-25, -36, 0],
#  [-40, 10, 0],
#  [26, 47, 1],
#  [31, -16, 1],
#  [29, 35, 1],
#  [22, -40, 0],
#  [-24, 40, 1],
#  [-25, 45, 1],
#  [23, -41, 0],
#  [40, 40, 1],
#  [40, -28, 1],
#  [21, -42, 0],
#  [-35, -35, 0],
#  [29, -13, 1],
#  [-35, 45, 1],
#  [-25, -35, 0],
#  [32, 49, 1],
#  [-40, 22, 0],
#  [-29, 48, 1],
#  [-36, -39, 0],
#  [-37, -31, 0],
#  [-32, -34, 0],
#  [40, -18, 1],
#  [26, -49, 0],
#  [23, 50, 1],
#  [-36, -32, 0],
#  [-40, -42, 0],
#  [-39, -45, 0],
#  [-20, 46, 1],
#  [27, 43, 1],
#  [-35, 14, 0],
#  [36, -50, 0],
#  [29, -50, 0],
#  [-20, 36, 1],
#  [-31, 15, 0],
#  [-21, 42, 1],
#  [36, 45, 1],
#  [30, -11, 1],
#  [21, -36, 0],
#  [-39, -44, 0],
#  [33, 34, 1],
#  [38, -15, 1],
#  [22, -38, 0],
#  [28, -11, 1],
#  [27, 44, 1],
#  [-32, -47, 0],
#  [-40, -40, 0],
#  [38, -28, 1],
#  [-20, 47, 1],
#  [34, -19, 1],
#  [28, -40, 0],
#  [20, -34, 0],
#  [-39, -36, 0],
#  [-23, 36, 1],
#  [27, -16, 1],
#  [32, 36, 1],
#  [-36, -32, 0],
#  [-22, 43, 1],
#  [-30, -39, 0],
#  [-32, 16, 0],
#  [24, 36, 1],
#  [-25, 44, 1],
#  [36, -13, 1],
#  [23, -43, 0],
#  [29, 31, 1],
#  [-21, 10, 0],
#  [32, 47, 1],
#  [21, -10, 1],
#  [29, 40, 1],
#  [-25, -30, 0],
#  [30, 31, 1],
#  [36, 45, 1],
#  [-28, 40, 1],
#  [35, -48, 0],
#  [35, 43, 1],
#  [29, -44, 0],
#  [-36, -35, 0],
#  [37, -13, 1],
#  [30, -45, 0],
#  [-27, 16, 0],
#  [-37, -30, 0],
#  [-34, -30, 0],
#  [21, 42, 1],
#  [39, -26, 1],
#  [-20, 40, 1],
#  [-39, -31, 0],
#  [40, 43, 1],
#  [-36, -49, 0],
#  [33, -49, 0],
#  [-31, -31, 0],
#  [25, 49, 1],
#  [34, 34, 1],
#  [28, -39, 0],
#  [27, 34, 1],
#  [-25, -34, 0],
#  [-29, -47, 0],
#  [-38, 14, 0],
#  [-32, 16, 0],
#  [-32, 44, 1],
#  [-32, 45, 1],
#  [39, -26, 1],
#  [36, -10, 1],
#  [-21, 37, 1],
#  [-20, -38, 0],
#  [22, -47, 0],
#  [29, -41, 0],
#  [-32, -30, 0],
#  [28, -15, 1],
#  [-23, -31, 0],
#  [32, 50, 1],
#  [26, -49, 0],
#  [25, -38, 0],
#  [29, 47, 1],
#  [30, -18, 1],
#  [30, 42, 1],
#  [26, -13, 1],
#  [-31, 15, 0],
#  [-23, -42, 0],
#  [-34, 47, 1],
#  [-29, -44, 0],
#  [35, 41, 1],
#  [-32, 12, 0],
#  [30, -15, 1],
#  [31, -21, 1],
#  [-26, -34, 0],
#  [-36, 23, 0],
#  [-35, -50, 0],
#  [-25, 48, 1],
#  [31, 31, 1],
#  [-33, 19, 0],
#  [-40, 11, 0],
#  [-34, 16, 0],
#  [21, -47, 0],
#  [-39, -37, 0],
#  [36, 37, 1],
#  [-24, -31, 0],
#  [40, 48, 1],
#  [-32, 49, 1],
#  [-30, 40, 1],
#  [-35, 19, 0],
#  [36, 35, 1],
#  [-40, -37, 0],
#  [25, 38, 1],
#  [32, -19, 1],
#  [-23, 41, 1],
#  [-21, -36, 0],
#  [-32, -31, 0],
#  [23, -39, 0],
#  [25, -11, 1],
#  [-25, 45, 1],
#  [-27, 37, 1],
#  [40, -23, 1],
#  [-33, -32, 0],
#  [-39, 12, 0],
#  [-39, 15, 0],
#  [-37, -40, 0],
#  [-28, 17, 0],
#  [25, -40, 0],
#  [-36, -44, 0],
#  [40, -30, 1],
#  [-20, -46, 0],
#  [-24, -41, 0],
#  [-39, 18, 0],
#  [-31, 13, 0],
#  [-30, 42, 1],
#  [-21, -39, 0],
#  [-36, 21, 0],
#  [-39, -36, 0],
#  [36, 48, 1],
#  [-20, -30, 0],
#  [-40, -30, 0],
#  [25, -12, 1],
#  [28, -17, 1],
#  [28, 49, 1],
#  [-32, -45, 0],
#  [38, -21, 1],
#  [-31, -44, 0],
#  [20, 31, 1],
#  [-38, -41, 0],
#  [-29, -46, 0],
#  [-27, -49, 0],
#  [29, 45, 1],
#  [-38, -34, 0],
#  [-26, 48, 1],
#  [32, -10, 1],
#  [33, -20, 1],
#  [-34, 13, 0],
#  [35, 37, 1],
#  [-32, -43, 0],
#  [39, 48, 1],
#  [20, 46, 1],
#  [23, -46, 0],
#  [-24, -48, 0],
#  [-22, 49, 1],
#  [27, 35, 1],
#  [-35, 46, 1],
#  [36, 36, 1],
#  [-22, -46, 0],
#  [-34, 50, 1],
#  [-22, -47, 0],
#  [-27, 45, 1],
#  [-23, -34, 0],
#  [38, -17, 1],
#  [-31, -30, 0],
#  [27, -14, 1],
#  [-23, -41, 0],
#  [-24, 50, 1],
#  [-39, 12, 0],
#  [-21, -48, 0],
#  [32, 30, 1],
#  [-34, 14, 0],
#  [-37, 10, 0],
#  [33, 48, 1],
#  [31, 36, 1],
#  [-36, 14, 0],
#  [32, -45, 0],
#  [-20, -41, 0],
#  [32, -10, 1],
#  [28, -10, 1],
#  [-39, 18, 0],
#  [24, 41, 1],
#  [37, -25, 1],
#  [39, -17, 1],
#  [-33, 14, 0],
#  [33, -15, 1],
#  [37, 38, 1],
#  [30, -44, 0],
#  [-30, -40, 0],
#  [-39, 25, 0],
#  [-32, 47, 1],
#  [-33, 15, 0],
#  [-34, -43, 0],
#  [-39, -35, 0],
#  [-27, -34, 0],
#  [34, 32, 1],
#  [20, 43, 1],
#  [-34, -42, 0],
#  [33, 42, 1],
#  [-21, 36, 1],
#  [30, 42, 1],
#  [-20, -45, 0],
#  [39, -27, 1],
#  [34, 38, 1],
#  [28, 43, 1],
#  [25, -39, 0],
#  [-21, 34, 1],
#  [-26, 12, 0],
#  [26, -12, 1],
#  [-39, 24, 0],
#  [40, 30, 1],
#  [29, -19, 1],
#  [-27, -42, 0],
#  [30, 40, 1],
#  [-37, -43, 0],
#  [-21, 42, 1],
#  [-31, -47, 0],
#  [-37, -30, 0],
#  [-40, -45, 0],
#  [-25, -49, 0],
#  [-22, 32, 1],
#  [-27, -43, 0],
#  [-30, -43, 0],
#  [-22, 48, 1],
#  [-33, -38, 0],
#  [36, 39, 1],
#  [-27, -43, 0],
#  [37, -13, 1],
#  [-24, 46, 1],
#  [-39, -50, 0],
#  [30, 48, 1],
#  [-27, -41, 0],
#  [-22, 37, 1],
#  [-33, -42, 0],
#  [23, -45, 0],
#  [-27, 13, 0],
#  [-26, -39, 0],
#  [40, -12, 1],
#  [37, 43, 1],
#  [26, -11, 1],
#  [36, -13, 1],
#  [-33, -49, 0],
#  [-20, 50, 1],
#  [28, 31, 1],
#  [-35, 19, 0],
#  [-39, 49, 1],
#  [-20, 40, 1],
#  [-33, 14, 0],
#  [-25, 41, 1],
#  [-24, -46, 0],
#  [40, 35, 1],
#  [-32, 12, 0],
#  [25, -11, 1],
#  [-22, -36, 0],
#  [-29, 12, 0],
#  [-28, -49, 0],
#  [36, -16, 1],
#  [-38, 12, 0],
#  [36, -49, 0],
#  [20, 38, 1],
#  [29, 44, 1],
#  [-32, -46, 0],
#  [35, -19, 1],
#  [-32, 48, 1],
#  [-35, -38, 0],
#  [23, 42, 1],
#  [-29, 44, 1],
#  [-22, -46, 0],
#  [-36, -34, 0],
#  [32, -45, 0],
#  [34, -23, 1],
#  [21, -35, 0],
#  [-24, -32, 0],
#  [21, -41, 0],
#  [-34, 17, 0],
#  [-27, 48, 1],
#  [-34, -43, 0],
#  [35, 44, 1],
#  [-35, 20, 0],
#  [-38, -46, 0],
#  [-35, -40, 0],
#  [40, -16, 1],
#  [39, 33, 1],
#  [-20, -32, 0],
#  [28, -14, 1],
#  [-27, 46, 1],
#  [31, -44, 0],
#  [-36, -41, 0],
#  [24, -37, 0],
#  [40, -23, 1],
#  [28, 34, 1],
#  [-40, -32, 0],
#  [30, -14, 1],
#  [-21, 32, 1],
#  [39, 50, 1],
#  [-22, -48, 0],
#  [31, -20, 1],
#  [-32, 42, 1],
#  [-38, 24, 0],
#  [24, 32, 1],
#  [-22, 45, 1],
#  [-20, -33, 0],
#  [-25, -40, 0],
#  [35, 31, 1],
#  [-22, 45, 1],
#  [-23, -47, 0],
#  [24, 48, 1],
#  [-24, -36, 0],
#  [-36, -30, 0],
#  [35, -20, 1],
#  [-36, 15, 0],
#  [-26, 41, 1],
#  [-32, 14, 0],
#  [-20, 44, 1],
#  [25, -46, 0],
#  [39, 42, 1],
#  [-25, -36, 0],
#  [39, -24, 1],
#  [33, 35, 1],
#  [-34, 12, 0],
#  [24, -40, 0],
#  [35, 32, 1],
#  [-26, -35, 0],
#  [22, -12, 1],
#  [39, 49, 1],
#  [-22, 39, 1],
#  [-32, 50, 1],
#  [31, -48, 0],
#  [32, -49, 0],
#  [36, 36, 1],
#  [-23, -39, 0],
#  [-39, -42, 0],
#  [-27, 11, 0],
#  [-36, -39, 0],
#  [-22, -43, 0],
#  [28, 41, 1],
#  [-35, -48, 0],
#  [-23, -50, 0],
#  [21, -47, 0],
#  [26, -47, 0],
#  [-35, -47, 0],
#  [-20, -39, 0],
#  [33, -46, 0],
#  [-24, -32, 0],
#  [34, -23, 1],
#  [36, -10, 1],
#  [31, 39, 1],
#  [-38, 25, 0],
#  [39, 34, 1],
#  [23, -48, 0],
#  [24, -49, 0],
#  [40, 41, 1],
#  [34, -14, 1],
#  [34, 49, 1],
#  [-27, 45, 1],
#  [27, 37, 1],
#  [26, -48, 0],
#  [24, 34, 1],
#  [20, -48, 0],
#  [-23, 40, 1],
#  [-33, -36, 0],
#  [-30, -50, 0],
#  [-39, 23, 0],
#  [-34, -46, 0],
#  [-22, 38, 1],
#  [35, -16, 1],
#  [-23, -49, 0],
#  [28, 42, 1],
#  [-32, -32, 0],
#  [-33, 43, 1],
#  [-34, -40, 0],
#  [-31, -46, 0],
#  [-31, -44, 0],
#  [-21, -31, 0],
#  [-30, 18, 0],
#  [27, 36, 1],
#  [-20, -36, 0],
#  [24, 33, 1],
#  [-22, 40, 1],
#  [28, 50, 1],
#  [36, -26, 1],
#  [-20, -39, 0],
#  [36, 42, 1],
#  [-25, -39, 0],
#  [-24, -36, 0],
#  [31, -43, 0],
#  [-27, -41, 0],
#  [33, -44, 0],
#  [-37, -33, 0],
#  [30, -11, 1],
#  [-22, -42, 0],
#  [25, 45, 1],
#  [31, -18, 1],
#  [38, -25, 1],
#  [-31, -30, 0],
#  [34, -15, 1],
#  [-37, 10, 0],
#  [34, 50, 1],
#  [35, 40, 1],
#  [-21, -48, 0],
#  [20, -49, 0],
#  [27, 46, 1],
#  [35, 45, 1],
#  [25, 42, 1],
#  [37, -17, 1],
#  [-38, -32, 0],
#  [30, -43, 0],
#  [-35, -39, 0],
#  [26, 34, 1],
#  [-21, -33, 0],
#  [30, -50, 0],
#  [-30, -40, 0],
#  [31, -17, 1],
#  [-24, 13, 0],
#  [35, -22, 1],
#  [25, 40, 1],
#  [-39, 26, 0],
#  [34, 44, 1],
#  [39, -28, 1],
#  [29, 34, 1],
#  [-33, -45, 0],
#  [-23, -38, 0],
#  [-33, -35, 0],
#  [-22, 40, 1],
#  [-25, -32, 0],
#  [-38, -36, 0],
#  [35, 46, 1],
#  [40, 42, 1],
#  [34, 49, 1],
#  [30, 49, 1],
#  [-32, 14, 0],
#  [40, 36, 1],
#  [23, -42, 0],
#  [31, -47, 0],
#  [38, -27, 1],
#  [-35, 12, 0],
#  [40, -19, 1],
#  [-27, -44, 0],
#  [-28, 50, 1],
#  [-23, -33, 0],
#  [-27, -42, 0],
#  [27, -16, 1],
#  [-20, 45, 1],
#  [-29, -35, 0],
#  [23, 48, 1],
#  [25, -43, 0],
#  [27, 33, 1],
#  [-23, 12, 0],
#  [-36, -45, 0],
#  [37, 44, 1],
#  [-34, 23, 0],
#  [-30, -36, 0],
#  [-24, -41, 0],
#  [36, 39, 1],
#  [39, 43, 1],
#  [35, -22, 1],
#  [38, -17, 1],
#  [28, 50, 1],
#  [-33, -50, 0],
#  [-21, -43, 0],
#  [24, 31, 1],
#  [28, -12, 1],
#  [35, 50, 1],
#  [-34, -39, 0],
#  [23, 40, 1],
#  [34, -22, 1],
#  [23, -37, 0],
#  [32, 37, 1],
#  [-30, -36, 0],
#  [33, 30, 1],
#  [-37, 13, 0],
#  [35, 30, 1],
#  [27, -39, 0],
#  [-32, -41, 0],
#  [34, -11, 1],
#  [-21, -37, 0],
#  [-29, 43, 1],
#  [30, 46, 1],
#  [-30, -40, 0],
#  [-37, -37, 0],
#  [-31, 20, 0],
#  [-28, -32, 0],
#  [-29, -43, 0],
#  [39, -50, 0],
#  [23, 38, 1],
#  [-36, 10, 0],
#  [-24, 45, 1],
#  [-27, -43, 0],
#  [-39, 11, 0],
#  [23, 41, 1],
#  [-37, 25, 0],
#  [-33, -30, 0],
#  [27, 41, 1],
#  [-23, -34, 0],
#  [-21, -45, 0],
#  [30, -45, 0],
#  [28, -40, 0],
#  [-23, 50, 1],
#  [-36, 50, 1],
#  [-36, 10, 0],
#  [37, -25, 1],
#  [-22, -33, 0],
#  [35, -11, 1],
#  [-29, -37, 0],
#  [29, -50, 0],
#  [-39, -32, 0],
#  [24, -12, 1],
#  [-32, 44, 1],
#  [29, -12, 1],
#  [38, 35, 1],
#  [-22, -40, 0],
#  [22, 42, 1],
#  [-37, -39, 0],
#  [30, -10, 1],
#  [-25, 11, 0],
#  [-20, -41, 0],
#  [32, 42, 1],
#  [-20, -44, 0],
#  [-27, 42, 1],
#  [-35, -40, 0],
#  [-27, 49, 1],
#  [-30, 48, 1],
#  [22, 40, 1],
#  [21, -41, 0],
#  [33, 50, 1],
#  [35, 31, 1],
#  [28, -15, 1],
#  [-29, -48, 0],
#  [-28, 45, 1],
#  [39, -27, 1],
#  [-25, -30, 0],
#  [36, 32, 1],
#  [26, -49, 0],
#  [21, 35, 1],
#  [34, -20, 1],
#  [-23, -49, 0],
#  [-39, 25, 0],
#  [-22, 10, 0],
#  [20, 37, 1],
#  [33, -44, 0],
#  [-40, 21, 0],
#  [-28, -47, 0],
#  [22, 32, 1],
#  [-35, 23, 0],
#  [37, 39, 1],
#  [34, 50, 1],
#  [-22, 37, 1],
#  [-22, -40, 0],
#  [30, -47, 0],
#  [-38, 13, 0],
#  [-25, -38, 0],
#  [-30, 19, 0],
#  [33, 33, 1],
#  [-28, -36, 0],
#  [39, -17, 1],
#  [28, -13, 1],
#  [-27, 38, 1],
#  [34, -19, 1],
#  [-39, 18, 0],
#  [-39, -40, 0],
#  [-22, -31, 0],
#  [25, 44, 1],
#  [26, -49, 0],
#  [-36, -45, 0],
#  [-31, 11, 0],
#  [-21, 31, 1],
#  [-25, -45, 0],
#  [-28, 48, 1],
#  [-24, 50, 1],
#  [-34, 13, 0],
#  [31, -18, 1],
#  [30, 40, 1],
#  [-39, 20, 0],
#  [-40, 11, 0],
#  [-27, -34, 0],
#  [22, -40, 0],
#  [22, -42, 0],
#  [23, 38, 1],
#  [-31, 16, 0],
#  [39, -24, 1],
#  [26, -47, 0],
#  [-39, 20, 0],
#  [-38, -31, 0],
#  [-36, 49, 1],
#  [31, 45, 1],
#  [39, 50, 1],
#  [-29, -36, 0],
#  [-34, -37, 0],
#  [31, -14, 1],
#  [-22, -48, 0],
#  [-23, -48, 0],
#  [-26, -41, 0],
#  [-31, 19, 0],
#  [26, 40, 1],
#  [-25, 41, 1],
#  [-20, 38, 1],
#  [-38, 50, 1],
#  [-37, -50, 0],
#  [-40, 11, 0],
#  [-40, 13, 0],
#  [-30, 17, 0],
#  [33, 49, 1],
#  [-28, -37, 0],
#  [30, -44, 0],
#  [26, 35, 1],
#  [39, -24, 1],
#  [-38, 21, 0],
#  [40, 45, 1],
#  [30, -20, 1],
#  [-37, 18, 0],
#  [38, -11, 1],
#  [26, 50, 1],
#  [-22, -45, 0],
#  [26, 36, 1],
#  [-39, 16, 0],
#  [27, -46, 0],
#  [-22, -44, 0],
#  [-39, -40, 0],
#  [27, 46, 1],
#  [29, 40, 1],
#  [25, -13, 1],
#  [24, 34, 1],
#  [39, -15, 1],
#  [-29, 18, 0],
#  [-22, 32, 1],
#  [40, 45, 1],
#  [39, -21, 1],
#  [24, -40, 0],
#  [-32, 49, 1],
#  [35, -15, 1],
#  [34, 33, 1],
#  [-22, 41, 1],
#  [32, 46, 1],
#  [25, -43, 0],
#  [25, -42, 0],
#  [40, -15, 1],
#  [-35, 50, 1],
#  [-24, -41, 0],
#  [-22, -30, 0],
#  [-27, -35, 0],
#  [-39, 21, 0],
#  [-32, -35, 0],
#  [-20, -32, 0],
#  [32, -22, 1],
#  [-36, 49, 1],
#  [-36, -47, 0],
#  [-35, -48, 0],
#  [-23, 37, 1],
#  [35, 47, 1],
#  [35, 36, 1],
#  [20, -41, 0],
#  [34, -12, 1],
#  [38, -21, 1],
#  [-26, -42, 0],
#  [22, -47, 0],
#  [-32, -38, 0],
#  [27, -43, 0],
#  [22, 32, 1],
#  [23, 46, 1],
#  [-34, -43, 0],
#  [-35, -46, 0],
#  [-38, 15, 0],
#  [-39, 25, 0],
#  [-40, -35, 0],
#  [-35, 16, 0],
#  [-30, -30, 0],
#  [28, 36, 1],
#  [-27, 49, 1],
#  [-34, -32, 0],
#  [-30, 41, 1],
#  [-32, 20, 0],
#  [39, -10, 1],
#  [21, -41, 0],
#  [22, -33, 0],
#  [20, 50, 1],
#  [33, 50, 1],
#  [21, -32, 0],
#  [35, 41, 1],
#  [31, -16, 1],
#  [-21, -47, 0],
#  [-29, 16, 0],
#  [-38, -47, 0],
#  [33, 41, 1],
#  [27, 32, 1],
#  [-33, -50, 0],
#  [-21, -40, 0],
#  [29, 31, 1],
#  [-40, -37, 0],
#  [23, 32, 1],
#  [-40, -34, 0],
#  [-28, -40, 0],
#  [22, 32, 1],
#  [-20, 31, 1],
#  [35, 45, 1],
#  [20, -42, 0],
#  [30, -49, 0],
#  [36, 31, 1],
#  [-26, 12, 0],
#  [37, 30, 1],
#  [-37, 21, 0],
#  [-29, 15, 0],
#  [33, -23, 1],
#  [-27, -43, 0],
#  [24, 44, 1],
#  [-31, 46, 1],
#  [-22, 46, 1],
#  [-40, -48, 0],
#  [-25, -33, 0],
#  [-34, -35, 0],
#  [38, 36, 1],
#  [-40, -41, 0],
#  [-32, -44, 0],
#  [-33, 47, 1],
#  [24, -36, 0],
#  [-31, 14, 0],
#  [-24, -33, 0],
#  [-33, -36, 0],
#  [-37, 18, 0],
#  [28, -43, 0],
#  [26, -14, 1],
#  [-35, 46, 1],
#  [-26, -38, 0],
#  [28, -17, 1],
#  [-24, 37, 1],
#  [28, 39, 1],
#  [-27, -33, 0],
#  [-30, -45, 0],
#  [-21, 47, 1],
#  [24, 34, 1],
#  [28, 48, 1],
#  [-31, 46, 1],
#  [28, -11, 1],
#  [21, -45, 0],
#  [29, 41, 1],
#  [-30, -43, 0],
#  [24, -37, 0],
#  [-21, -34, 0],
#  [-29, 17, 0],
#  [-26, 10, 0],
#  [35, -25, 1],
#  [40, -29, 1],
#  [-32, 10, 0],
#  [31, -18, 1],
#  [30, -45, 0],
#  [-27, 14, 0],
#  [-21, -44, 0],
#  [36, 49, 1],
#  [21, -47, 0],
#  [-23, 36, 1],
#  [-32, -33, 0],
#  [-32, -49, 0],
#  [-24, 49, 1],
#  [-28, 49, 1],
#  [35, 42, 1],
#  [-39, 22, 0],
#  [29, -15, 1],
#  [-26, 50, 1],
#  [39, -29, 1],
#  [24, -37, 0],
#  [-39, 13, 0],
#  [32, -45, 0],
#  [28, 37, 1],
#  [-35, -46, 0],
#  [-38, -41, 0],
#  [26, 42, 1],
#  [-29, -48, 0],
#  [22, -38, 0],
#  [25, -46, 0],
#  [-25, 46, 1],
#  [-20, 49, 1],
#  [34, -17, 1],
#  [-26, 15, 0],
#  [27, -42, 0],
#  ...]

# %%
def point_multiply(point1,w):
    counts = 0
    for index in range(num_dim):
        counts = counts + point1[index]* w[index]
    return counts

# %%
tmp_counts = point_multiply(points_list[0],w)
tmp_counts
# Out:
# 0

# %%
# 违反返回true,不违反返回false
def check_violation(point1,w):
    sum_result = point_multiply(point1,w)
    # 标签为 1 时
    if point1[num_dim] == 1:
        if sum_result <= 0:
            return True
        else:
            return False
    # 标签为 0 时
    else:
        if sum_result >= 0:
            return True
        else:
            return False

# %%
def perceptron(point_list,w):
    global violation_times
    is_violation = False
    for point_index in range(len(point_list)):
        is_violation = check_violation(point_list[point_index],w)
        if (is_violation == True ):
            if (point_list[point_index][num_dim] == 1):
                for update_index in range(len(w)):
                    w[update_index] = w[update_index] + point_list[point_index][update_index]
            else:
                for update_index in range(len(w)):
                    w[update_index] = w[update_index] - point_list[point_index][update_index]
            print("Violation time # {},The violation happens at # {} point".format(violation_times+1,point_index+1))
            print("The w is adjusted to {}".format(w))
            violation_times = violation_times + 1
            return False
    print("No violation happens ".format(w))
    return True

# %%
perceptron(points_list,w)
# Out:
# Violation time # 14,The violation happens at # 1 point
# The w is adjusted to [4, -1]
# No violation happens
# True

# %%
is_finish = False
violation_times = 0
while(is_finish == False):
    is_finish = perceptron(points_list,w)
print(violation_times)
# Out:
# Violation time # 1,The violation happens at # 1 point
# The w is adjusted to [-31, 47]
# Violation time # 2,The violation happens at # 3 point
# The w is adjusted to [7, 19]
# Violation time # 3,The violation happens at # 3 point
# The w is adjusted to [45, -9]
# Violation time # 4,The violation happens at # 1 point
# The w is adjusted to [14, 38]
# Violation time # 5,The violation happens at # 3 point
# The w is adjusted to [52, 10]
# Violation time # 6,The violation happens at # 1 point
# The w is adjusted to [21, 57]
# Violation time # 7,The violation happens at # 3 point
# The w is adjusted to [59, 29]
# Violation time # 8,The violation happens at # 1 point
# The w is adjusted to [28, 76]
# Violation time # 9,The violation happens at # 3 point
# The w is adjusted to [66, 48]
# Violation time # 10,The violation happens at # 4 point
# The w is adjusted to [32, 94]
# Violation time # 11,The violation happens at # 3 point
# The w is adjusted to [70, 66]
# No violation happens
# 11

# %%
def point_square(point):
    R = 0
    for i in range(num_dim):
        R = R + point[i] * point[i]
    return R

# %%
tmp = point_square(w)
tmp
# Out:
# 5

# %%
tmp ** 0.5
# Out:
# 2.23606797749979

# %%
def find_R(points_list):
    tmp_R = 0
    for i in range(num_point):
        this_R = point_square(points_list[i])
        if(this_R > tmp_R):
            tmp_R = this_R
    return tmp_R

# %%
9722**2 + 8374

# %%
biggest_R = find_R(points_list)
biggest_R
# Out:
# 115217049

# %%
biggest_R ** 0.5
# Out:
# 10733.920486010691

# %%
def dis_pt_to_plane(points,w):
    distance = 0
    w_denominator = point_square(w)
    w_denominator = w_denominator ** 0.5
    for i in range(num_dim):
        distance = distance + points[i]*w[i]
    #absolute
    result = abs(distance / w_denominator)
    # round set to 3
    result = round(result,3)
    return result

# %%
dis = dis_pt_to_plane(points_list[0],w)
dis
# Out:
# 2.236

# %%
def check_violation_distance(point,w,r_guess):
    r_guess_half = r_guess / 2
    dist_to_plane = dis_pt_to_plane(point,w)
    if dist_to_plane < r_guess_half :
        return True
    else:
        return False

# %%
def perceptron_distance(points_list,w,r_guess):
    global violation_times
    for i in range(num_point):
        # define a flag
        is_distance_violation = check_violation_distance(points_list[i],w,r_guess)
        # if violation happens
        if(is_distance_violation):
            if (points_list[i][num_dim] == 1):
                for update_index in range(len(w)):
                    w[update_index] = w[update_index] + points_list[i][update_index]
            else:
                for update_index in range(len(w)):
                    w[update_index] = w[update_index] - points_list[i][update_index]
            print("Violation time # {},The distance violation happens at # {} point".format(violation_times+1,i+1))
            print("The w is adjusted to {}".format(w))
            print("Redoing the normal perceptron")
            violation_times = violation_times + 1
            global is_finish_stage1
            is_finish_stage1 = False
            return False
    if(is_finish_stage1 == True):
        print("No distance violation happens".format(w))
        return True
    else:
        return False

# %%
def Initiate_w():
    global w
    w = [0]
    for i in range(num_dim-1):
        w.append(0)

# %%
def cal_terminate_time(points_list,r_guess):
    R = find_R(points_list)
    r_guess_tmp = r_guess * r_guess
    return (12*R/r_guess_tmp)

# %%
def Break_perceptron(points_list):
    global is_finish_stage1
    global is_finish_stage2
    global violation_times
    global r_guess
    termi_time = cal_terminate_time(points_list,r_guess)
    print('现在我们有 {} 次违例'.format(violation_times) )
    # 超过终止次数
    if(termi_time < violation_times):
        # 初始化，重新进行下一轮
        is_finish_stage1 = False
        is_finish_stage2 = False
        r_guess = r_guess / 2
        violation_times = 0
        Initiate_w()
        print('Violation次数超出限制，r_guess减小一倍')
    else:
        pass

# %%
# 建造w
w = [0]
for i in range(num_dim-1):
    w.append(0)
is_finish_stage1 = False
is_finish_stage2 = False
r_guess = find_R(points_list)
r_guess = round(r_guess** 0.5)
violation_times = 0
while(is_finish_stage1 == False or is_finish_stage2 == False):
    if(is_finish_stage1 == False and is_finish_stage2 == False):
        is_finish_stage1 = perceptron(points_list,w)
    elif(is_finish_stage1 == True and is_finish_stage2 == False):
        is_finish_stage2 = perceptron_distance(points_list,w,r_guess)
    elif(is_finish_stage1 == False and is_finish_stage2 == True):
        is_finish_stage1 = perceptron(points_list,w)
    #check whether it needs terminate
    Break_perceptron(points_list)
    print(r_guess)
print("The final w is {}".format(w))
print("We guarantee the margin to be at least {}".format(r_guess/2))
print("Total violation time is {}".format(violation_times))
# Out:
# Violation time # 1,The violation happens at # 1 point
# The w is adjusted to [-31, 47]
# 现在我们有 1 次违例
# 64
# Violation time # 2,The violation happens at # 3 point
# The w is adjusted to [7, 19]
# 现在我们有 2 次违例
# 64
# Violation time # 3,The violation happens at # 3 point
# The w is adjusted to [45, -9]
# 现在我们有 3 次违例
# 64
# Violation time # 4,The violation happens at # 1 point
# The w is adjusted to [14, 38]
# 现在我们有 4 次违例
# 64
# Violation time # 5,The violation happens at # 3 point
# The w is adjusted to [52, 10]
# 现在我们有 5 次违例
# 64
# Violation time # 6,The violation happens at # 1 point
# The w is adjusted to [21, 57]
# 现在我们有 6 次违例
# 64
# Violation time # 7,The violation happens at # 3 point
# The w is adjusted to [59, 29]
# 现在我们有 7 次违例
# 64
# Violation time # 8,The violation happens at # 1 point
# The w is adjusted to [28, 76]
# 现在我们有 8 次违例
# 64
# Violation time # 9,The violation happens at # 3 point
# The w is adjusted to [66, 48]
# 现在我们有 9 次违例
# 64
# Violation time # 10,The violation happens at # 4 point
# The w is adjusted to [32, 94]
# 现在我们有 10 次违例
# 64
# Violation time # 11,The violation happens at # 3 point
# The w is adjusted to [70, 66]
# 现在我们有 11 次违例
# 64
# No violation happens
# 现在我们有 11 次违例
# 64
# Violation time # 12,The distance violation happens at # 1 point
# The w is adjusted to [39, 113]
# Redoing the normal perceptron
# 现在我们有 12 次违例
# 64
# Violation time # 13,The violation happens at # 3 point
# The w is adjusted to [77, 85]
# 现在我们有 13 次违例
# Violation次数超出限制，r_guess减小一倍
# 32.0
# Violation time # 1,The violation happens at # 1 point
# The w is adjusted to [-31, 47]
# 现在我们有 1 次违例
# 32.0
# Violation time # 2,The violation happens at # 3 point
# The w is adjusted to [7, 19]
# 现在我们有 2 次违例
# 32.0
# Violation time # 3,The violation happens at # 3 point
# The w is adjusted to [45, -9]
# 现在我们有 3 次违例
# 32.0
# Violation time # 4,The violation happens at # 1 point
# The w is adjusted to [14, 38]
# 现在我们有 4 次违例
# 32.0
# Violation time # 5,The violation happens at # 3 point
# The w is adjusted to [52, 10]
# 现在我们有 5 次违例
# 32.0
# Violation time # 6,The violation happens at # 1 point
# The w is adjusted to [21, 57]
# 现在我们有 6 次违例
# 32.0
# Violation time # 7,The violation happens at # 3 point
# The w is adjusted to [59, 29]
# 现在我们有 7 次违例
# 32.0
# Violation time # 8,The violation happens at # 1 point
# The w is adjusted to [28, 76]
# 现在我们有 8 次违例
# 32.0
# Violation time # 9,The violation happens at # 3 point
# The w is adjusted to [66, 48]
# 现在我们有 9 次违例
# 32.0
# Violation time # 10,The violation happens at # 4 point
# The w is adjusted to [32, 94]
# 现在我们有 10 次违例
# 32.0
# Violation time # 11,The violation happens at # 3 point
# The w is adjusted to [70, 66]
# 现在我们有 11 次违例
# 32.0
# No violation happens
# 现在我们有 11 次违例
# 32.0
# Violation time # 12,The distance violation happens at # 1 point
# The w is adjusted to [39, 113]
# Redoing the normal perceptron
# 现在我们有 12 次违例
# 32.0
# Violation time # 13,The violation happens at # 3 point
# The w is adjusted to [77, 85]
# 现在我们有 13 次违例
# 32.0
# No violation happens
# 现在我们有 13 次违例
# 32.0
# Violation time # 14,The distance violation happens at # 1 point
# The w is adjusted to [46, 132]
# Redoing the normal perceptron
# 现在我们有 14 次违例
# 32.0
# Violation time # 15,The violation happens at # 3 point
# The w is adjusted to [84, 104]
# 现在我们有 15 次违例
# 32.0
# No violation happens
# 现在我们有 15 次违例
# 32.0
# Violation time # 16,The distance violation happens at # 3 point
# The w is adjusted to [122, 76]
# Redoing the normal perceptron
# 现在我们有 16 次违例
# 32.0
# Violation time # 17,The violation happens at # 1 point
# The w is adjusted to [91, 123]
# 现在我们有 17 次违例
# 32.0
# Violation time # 18,The violation happens at # 348 point
# The w is adjusted to [131, 93]
# 现在我们有 18 次违例
# 32.0
# Violation time # 19,The violation happens at # 4 point
# The w is adjusted to [97, 139]
# 现在我们有 19 次违例
# 32.0
# Violation time # 20,The violation happens at # 3 point
# The w is adjusted to [135, 111]
# 现在我们有 20 次违例
# 32.0
# No violation happens
# 现在我们有 20 次违例
# 32.0
# Violation time # 21,The distance violation happens at # 1 point
# The w is adjusted to [104, 158]
# Redoing the normal perceptron
# 现在我们有 21 次违例
# 32.0
# Violation time # 22,The violation happens at # 3 point
# The w is adjusted to [142, 130]
# 现在我们有 22 次违例
# 32.0
# No violation happens
# 现在我们有 22 次违例
# 32.0
# Violation time # 23,The distance violation happens at # 1 point
# The w is adjusted to [111, 177]
# Redoing the normal perceptron
# 现在我们有 23 次违例
# 32.0
# Violation time # 24,The violation happens at # 3 point
# The w is adjusted to [149, 149]
# 现在我们有 24 次违例
# 32.0
# No violation happens
# 现在我们有 24 次违例
# 32.0
# Violation time # 25,The distance violation happens at # 1 point
# The w is adjusted to [118, 196]
# Redoing the normal perceptron
# 现在我们有 25 次违例
# 32.0
# Violation time # 26,The violation happens at # 3 point
# The w is adjusted to [156, 168]
# 现在我们有 26 次违例
# 32.0
# No violation happens
# 现在我们有 26 次违例
# 32.0
# Violation time # 27,The distance violation happens at # 1 point
# The w is adjusted to [125, 215]
# Redoing the normal perceptron
# 现在我们有 27 次违例
# 32.0
# Violation time # 28,The violation happens at # 3 point
# The w is adjusted to [163, 187]
# 现在我们有 28 次违例
# 32.0
# No violation happens
# 现在我们有 28 次违例
# 32.0
# Violation time # 29,The distance violation happens at # 1 point
# The w is adjusted to [132, 234]
# Redoing the normal perceptron
# 现在我们有 29 次违例
# 32.0
# Violation time # 30,The violation happens at # 3 point
# The w is adjusted to [170, 206]
# 现在我们有 30 次违例
# 32.0
# No violation happens
# 现在我们有 30 次违例
# 32.0
# Violation time # 31,The distance violation happens at # 3 point
# The w is adjusted to [208, 178]
# Redoing the normal perceptron
# 现在我们有 31 次违例
# 32.0
# No violation happens
# 现在我们有 31 次违例
# 32.0
# Violation time # 32,The distance violation happens at # 1 point
# The w is adjusted to [177, 225]
# Redoing the normal perceptron
# 现在我们有 32 次违例
# 32.0
# No violation happens
# 现在我们有 32 次违例
# 32.0
# Violation time # 33,The distance violation happens at # 3 point
# The w is adjusted to [215, 197]
# Redoing the normal perceptron
# 现在我们有 33 次违例
# 32.0
# No violation happens
# 现在我们有 33 次违例
# 32.0
# Violation time # 34,The distance violation happens at # 1 point
# The w is adjusted to [184, 244]
# Redoing the normal perceptron
# 现在我们有 34 次违例
# 32.0
# No violation happens
# 现在我们有 34 次违例
# 32.0
# Violation time # 35,The distance violation happens at # 3 point
# The w is adjusted to [222, 216]
# Redoing the normal perceptron
# 现在我们有 35 次违例
# 32.0
# No violation happens
# 现在我们有 35 次违例
# 32.0
# Violation time # 36,The distance violation happens at # 1 point
# The w is adjusted to [191, 263]
# Redoing the normal perceptron
# 现在我们有 36 次违例
# 32.0
# Violation time # 37,The violation happens at # 3 point
# The w is adjusted to [229, 235]
# 现在我们有 37 次违例
# 32.0
# No violation happens
# 现在我们有 37 次违例
# 32.0
# Violation time # 38,The distance violation happens at # 1 point
# The w is adjusted to [198, 282]
# Redoing the normal perceptron
# 现在我们有 38 次违例
# 32.0
# Violation time # 39,The violation happens at # 3 point
# The w is adjusted to [236, 254]
# 现在我们有 39 次违例
# 32.0
# No violation happens
# 现在我们有 39 次违例
# 32.0
# Violation time # 40,The distance violation happens at # 1 point
# The w is adjusted to [205, 301]
# Redoing the normal perceptron
# 现在我们有 40 次违例
# 32.0
# Violation time # 41,The violation happens at # 3 point
# The w is adjusted to [243, 273]
# 现在我们有 41 次违例
# 32.0
# No violation happens
# 现在我们有 41 次违例
# 32.0
# Violation time # 42,The distance violation happens at # 1 point
# The w is adjusted to [212, 320]
# Redoing the normal perceptron
# 现在我们有 42 次违例
# 32.0
# Violation time # 43,The violation happens at # 3 point
# The w is adjusted to [250, 292]
# 现在我们有 43 次违例
# 32.0
# No violation happens
# 现在我们有 43 次违例
# 32.0
# Violation time # 44,The distance violation happens at # 1 point
# The w is adjusted to [219, 339]
# Redoing the normal perceptron
# 现在我们有 44 次违例
# 32.0
# Violation time # 45,The violation happens at # 3 point
# The w is adjusted to [257, 311]
# 现在我们有 45 次违例
# 32.0
# No violation happens
# 现在我们有 45 次违例
# 32.0
# Violation time # 46,The distance violation happens at # 3 point
# The w is adjusted to [295, 283]
# Redoing the normal perceptron
# 现在我们有 46 次违例
# 32.0
# No violation happens
# 现在我们有 46 次违例
# 32.0
# Violation time # 47,The distance violation happens at # 1 point
# The w is adjusted to [264, 330]
# Redoing the normal perceptron
# 现在我们有 47 次违例
# 32.0
# No violation happens
# 现在我们有 47 次违例
# 32.0
# Violation time # 48,The distance violation happens at # 3 point
# The w is adjusted to [302, 302]
# Redoing the normal perceptron
# 现在我们有 48 次违例
# 32.0
# No violation happens
# 现在我们有 48 次违例
# 32.0
# Violation time # 49,The distance violation happens at # 1 point
# The w is adjusted to [271, 349]
# Redoing the normal perceptron
# 现在我们有 49 次违例
# Violation次数超出限制，r_guess减小一倍
# 16.0
# Violation time # 1,The violation happens at # 1 point
# The w is adjusted to [-31, 47]
# 现在我们有 1 次违例
# 16.0
# Violation time # 2,The violation happens at # 3 point
# The w is adjusted to [7, 19]
# 现在我们有 2 次违例
# 16.0
# Violation time # 3,The violation happens at # 3 point
# The w is adjusted to [45, -9]
# 现在我们有 3 次违例
# 16.0
# Violation time # 4,The violation happens at # 1 point
# The w is adjusted to [14, 38]
# 现在我们有 4 次违例
# 16.0
# Violation time # 5,The violation happens at # 3 point
# The w is adjusted to [52, 10]
# 现在我们有 5 次违例
# 16.0
# Violation time # 6,The violation happens at # 1 point
# The w is adjusted to [21, 57]
# 现在我们有 6 次违例
# 16.0
# Violation time # 7,The violation happens at # 3 point
# The w is adjusted to [59, 29]
# 现在我们有 7 次违例
# 16.0
# Violation time # 8,The violation happens at # 1 point
# The w is adjusted to [28, 76]
# 现在我们有 8 次违例
# 16.0
# Violation time # 9,The violation happens at # 3 point
# The w is adjusted to [66, 48]
# 现在我们有 9 次违例
# 16.0
# Violation time # 10,The violation happens at # 4 point
# The w is adjusted to [32, 94]
# 现在我们有 10 次违例
# 16.0
# Violation time # 11,The violation happens at # 3 point
# The w is adjusted to [70, 66]
# 现在我们有 11 次违例
# 16.0
# No violation happens
# 现在我们有 11 次违例
# 16.0
# Violation time # 12,The distance violation happens at # 4 point
# The w is adjusted to [36, 112]
# Redoing the normal perceptron
# 现在我们有 12 次违例
# 16.0
# Violation time # 13,The violation happens at # 3 point
# The w is adjusted to [74, 84]
# 现在我们有 13 次违例
# 16.0
# No violation happens
# 现在我们有 13 次违例
# 16.0
# Violation time # 14,The distance violation happens at # 3 point
# The w is adjusted to [112, 56]
# Redoing the normal perceptron
# 现在我们有 14 次违例
# 16.0
# Violation time # 15,The violation happens at # 1 point
# The w is adjusted to [81, 103]
# 现在我们有 15 次违例
# 16.0
# No violation happens
# 现在我们有 15 次违例
# 16.0
# Violation time # 16,The distance violation happens at # 3 point
# The w is adjusted to [119, 75]
# Redoing the normal perceptron
# 现在我们有 16 次违例
# 16.0
# Violation time # 17,The violation happens at # 1 point
# The w is adjusted to [88, 122]
# 现在我们有 17 次违例
# 16.0
# Violation time # 18,The violation happens at # 3 point
# The w is adjusted to [126, 94]
# 现在我们有 18 次违例
# 16.0
# Violation time # 19,The violation happens at # 127 point
# The w is adjusted to [88, 142]
# 现在我们有 19 次违例
# 16.0
# Violation time # 20,The violation happens at # 3 point
# The w is adjusted to [126, 114]
# 现在我们有 20 次违例
# 16.0
# No violation happens
# 现在我们有 20 次违例
# 16.0
# Violation time # 21,The distance violation happens at # 4 point
# The w is adjusted to [92, 160]
# Redoing the normal perceptron
# 现在我们有 21 次违例
# 16.0
# Violation time # 22,The violation happens at # 3 point
# The w is adjusted to [130, 132]
# 现在我们有 22 次违例
# 16.0
# No violation happens
# 现在我们有 22 次违例
# 16.0
# Violation time # 23,The distance violation happens at # 3 point
# The w is adjusted to [168, 104]
# Redoing the normal perceptron
# 现在我们有 23 次违例
# 16.0
# Violation time # 24,The violation happens at # 1 point
# The w is adjusted to [137, 151]
# 现在我们有 24 次违例
# 16.0
# No violation happens
# 现在我们有 24 次违例
# 16.0
# Violation time # 25,The distance violation happens at # 3 point
# The w is adjusted to [175, 123]
# Redoing the normal perceptron
# 现在我们有 25 次违例
# 16.0
# Violation time # 26,The violation happens at # 4 point
# The w is adjusted to [141, 169]
# 现在我们有 26 次违例
# 16.0
# No violation happens
# 现在我们有 26 次违例
# 16.0
# Violation time # 27,The distance violation happens at # 3 point
# The w is adjusted to [179, 141]
# Redoing the normal perceptron
# 现在我们有 27 次违例
# 16.0
# Violation time # 28,The violation happens at # 127 point
# The w is adjusted to [141, 189]
# 现在我们有 28 次违例
# 16.0
# Violation time # 29,The violation happens at # 348 point
# The w is adjusted to [181, 159]
# 现在我们有 29 次违例
# 16.0
# No violation happens
# 现在我们有 29 次违例
# 16.0
# Violation time # 30,The distance violation happens at # 1 point
# The w is adjusted to [150, 206]
# Redoing the normal perceptron
# 现在我们有 30 次违例
# 16.0
# Violation time # 31,The violation happens at # 3 point
# The w is adjusted to [188, 178]
# 现在我们有 31 次违例
# 16.0
# No violation happens
# 现在我们有 31 次违例
# 16.0
# Violation time # 32,The distance violation happens at # 4 point
# The w is adjusted to [154, 224]
# Redoing the normal perceptron
# 现在我们有 32 次违例
# 16.0
# Violation time # 33,The violation happens at # 3 point
# The w is adjusted to [192, 196]
# 现在我们有 33 次违例
# 16.0
# No violation happens
# 现在我们有 33 次违例
# 16.0
# Violation time # 34,The distance violation happens at # 3 point
# The w is adjusted to [230, 168]
# Redoing the normal perceptron
# 现在我们有 34 次违例
# 16.0
# Violation time # 35,The violation happens at # 4 point
# The w is adjusted to [196, 214]
# 现在我们有 35 次违例
# 16.0
# No violation happens
# 现在我们有 35 次违例
# 16.0
# Violation time # 36,The distance violation happens at # 3 point
# The w is adjusted to [234, 186]
# Redoing the normal perceptron
# 现在我们有 36 次违例
# 16.0
# Violation time # 37,The violation happens at # 187 point
# The w is adjusted to [194, 236]
# 现在我们有 37 次违例
# 16.0
# No violation happens
# 现在我们有 37 次违例
# 16.0
# Violation time # 38,The distance violation happens at # 3 point
# The w is adjusted to [232, 208]
# Redoing the normal perceptron
# 现在我们有 38 次违例
# 16.0
# No violation happens
# 现在我们有 38 次违例
# 16.0
# Violation time # 39,The distance violation happens at # 4 point
# The w is adjusted to [198, 254]
# Redoing the normal perceptron
# 现在我们有 39 次违例
# 16.0
# No violation happens
# 现在我们有 39 次违例
# 16.0
# Violation time # 40,The distance violation happens at # 3 point
# The w is adjusted to [236, 226]
# Redoing the normal perceptron
# 现在我们有 40 次违例
# 16.0
# No violation happens
# 现在我们有 40 次违例
# 16.0
# Violation time # 41,The distance violation happens at # 4 point
# The w is adjusted to [202, 272]
# Redoing the normal perceptron
# 现在我们有 41 次违例
# 16.0
# Violation time # 42,The violation happens at # 348 point
# The w is adjusted to [242, 242]
# 现在我们有 42 次违例
# 16.0
# No violation happens
# 现在我们有 42 次违例
# 16.0
# Violation time # 43,The distance violation happens at # 3 point
# The w is adjusted to [280, 214]
# Redoing the normal perceptron
# 现在我们有 43 次违例
# 16.0
# Violation time # 44,The violation happens at # 127 point
# The w is adjusted to [242, 262]
# 现在我们有 44 次违例
# 16.0
# No violation happens
# 现在我们有 44 次违例
# 16.0
# Violation time # 45,The distance violation happens at # 3 point
# The w is adjusted to [280, 234]
# Redoing the normal perceptron
# 现在我们有 45 次违例
# 16.0
# No violation happens
# 现在我们有 45 次违例
# 16.0
# Violation time # 46,The distance violation happens at # 1 point
# The w is adjusted to [249, 281]
# Redoing the normal perceptron
# 现在我们有 46 次违例
# 16.0
# No violation happens
# 现在我们有 46 次违例
# 16.0
# Violation time # 47,The distance violation happens at # 3 point
# The w is adjusted to [287, 253]
# Redoing the normal perceptron
# 现在我们有 47 次违例
# 16.0
# No violation happens
# 现在我们有 47 次违例
# 16.0
# Violation time # 48,The distance violation happens at # 1 point
# The w is adjusted to [256, 300]
# Redoing the normal perceptron
# 现在我们有 48 次违例
# 16.0
# No violation happens
# 现在我们有 48 次违例
# 16.0
# Violation time # 49,The distance violation happens at # 3 point
# The w is adjusted to [294, 272]
# Redoing the normal perceptron
# 现在我们有 49 次违例
# 16.0
# No violation happens
# 现在我们有 49 次违例
# 16.0
# Violation time # 50,The distance violation happens at # 4 point
# The w is adjusted to [260, 318]
# Redoing the normal perceptron
# 现在我们有 50 次违例
# 16.0
# No violation happens
# 现在我们有 50 次违例
# 16.0
# Violation time # 51,The distance violation happens at # 3 point
# The w is adjusted to [298, 290]
# Redoing the normal perceptron
# 现在我们有 51 次违例
# 16.0
# No violation happens
# 现在我们有 51 次违例
# 16.0
# Violation time # 52,The distance violation happens at # 3 point
# The w is adjusted to [336, 262]
# Redoing the normal perceptron
# 现在我们有 52 次违例
# 16.0
# Violation time # 53,The violation happens at # 127 point
# The w is adjusted to [298, 310]
# 现在我们有 53 次违例
# 16.0
# No violation happens
# 现在我们有 53 次违例
# 16.0
# Violation time # 54,The distance violation happens at # 3 point
# The w is adjusted to [336, 282]
# Redoing the normal perceptron
# 现在我们有 54 次违例
# 16.0
# No violation happens
# 现在我们有 54 次违例
# 16.0
# Violation time # 55,The distance violation happens at # 1 point
# The w is adjusted to [305, 329]
# Redoing the normal perceptron
# 现在我们有 55 次违例
# 16.0
# No violation happens
# 现在我们有 55 次违例
# 16.0
# Violation time # 56,The distance violation happens at # 3 point
# The w is adjusted to [343, 301]
# Redoing the normal perceptron
# 现在我们有 56 次违例
# 16.0
# No violation happens
# 现在我们有 56 次违例
# 16.0
# Violation time # 57,The distance violation happens at # 1 point
# The w is adjusted to [312, 348]
# Redoing the normal perceptron
# 现在我们有 57 次违例
# 16.0
# No violation happens
# 现在我们有 57 次违例
# 16.0
# Violation time # 58,The distance violation happens at # 3 point
# The w is adjusted to [350, 320]
# Redoing the normal perceptron
# 现在我们有 58 次违例
# 16.0
# No violation happens
# 现在我们有 58 次违例
# 16.0
# Violation time # 59,The distance violation happens at # 4 point
# The w is adjusted to [316, 366]
# Redoing the normal perceptron
# 现在我们有 59 次违例
# 16.0
# No violation happens
# 现在我们有 59 次违例
# 16.0
# Violation time # 60,The distance violation happens at # 3 point
# The w is adjusted to [354, 338]
# Redoing the normal perceptron
# 现在我们有 60 次违例
# 16.0
# No violation happens
# 现在我们有 60 次违例
# 16.0
# Violation time # 61,The distance violation happens at # 4 point
# The w is adjusted to [320, 384]
# Redoing the normal perceptron
# 现在我们有 61 次违例
# 16.0
# No violation happens
# 现在我们有 61 次违例
# 16.0
# Violation time # 62,The distance violation happens at # 3 point
# The w is adjusted to [358, 356]
# Redoing the normal perceptron
# 现在我们有 62 次违例
# 16.0
# No violation happens
# 现在我们有 62 次违例
# 16.0
# Violation time # 63,The distance violation happens at # 3 point
# The w is adjusted to [396, 328]
# Redoing the normal perceptron
# 现在我们有 63 次违例
# 16.0
# No violation happens
# 现在我们有 63 次违例
# 16.0
# Violation time # 64,The distance violation happens at # 1 point
# The w is adjusted to [365, 375]
# Redoing the normal perceptron
# 现在我们有 64 次违例
# 16.0
# No violation happens
# 现在我们有 64 次违例
# 16.0
# Violation time # 65,The distance violation happens at # 3 point
# The w is adjusted to [403, 347]
# Redoing the normal perceptron
# 现在我们有 65 次违例
# 16.0
# No violation happens
# 现在我们有 65 次违例
# 16.0
# Violation time # 66,The distance violation happens at # 1 point
# The w is adjusted to [372, 394]
# Redoing the normal perceptron
# 现在我们有 66 次违例
# 16.0
# No violation happens
# 现在我们有 66 次违例
# 16.0
# Violation time # 67,The distance violation happens at # 3 point
# The w is adjusted to [410, 366]
# Redoing the normal perceptron
# 现在我们有 67 次违例
# 16.0
# No violation happens
# 现在我们有 67 次违例
# 16.0
# Violation time # 68,The distance violation happens at # 4 point
# The w is adjusted to [376, 412]
# Redoing the normal perceptron
# 现在我们有 68 次违例
# 16.0
# No violation happens
# 现在我们有 68 次违例
# 16.0
# Violation time # 69,The distance violation happens at # 3 point
# The w is adjusted to [414, 384]
# Redoing the normal perceptron
# 现在我们有 69 次违例
# 16.0
# No violation happens
# 现在我们有 69 次违例
# 16.0
# Violation time # 70,The distance violation happens at # 4 point
# The w is adjusted to [380, 430]
# Redoing the normal perceptron
# 现在我们有 70 次违例
# 16.0
# No violation happens
# 现在我们有 70 次违例
# 16.0
# Violation time # 71,The distance violation happens at # 3 point
# The w is adjusted to [418, 402]
# Redoing the normal perceptron
# 现在我们有 71 次违例
# 16.0
# No violation happens
# 现在我们有 71 次违例
# 16.0
# Violation time # 72,The distance violation happens at # 3 point
# The w is adjusted to [456, 374]
# Redoing the normal perceptron
# 现在我们有 72 次违例
# 16.0
# No violation happens
# 现在我们有 72 次违例
# 16.0
# Violation time # 73,The distance violation happens at # 1 point
# The w is adjusted to [425, 421]
# Redoing the normal perceptron
# 现在我们有 73 次违例
# 16.0
# No violation happens
# 现在我们有 73 次违例
# 16.0
# Violation time # 74,The distance violation happens at # 3 point
# The w is adjusted to [463, 393]
# Redoing the normal perceptron
# 现在我们有 74 次违例
# 16.0
# No violation happens
# 现在我们有 74 次违例
# 16.0
# Violation time # 75,The distance violation happens at # 1 point
# The w is adjusted to [432, 440]
# Redoing the normal perceptron
# 现在我们有 75 次违例
# 16.0
# No violation happens
# 现在我们有 75 次违例
# 16.0
# Violation time # 76,The distance violation happens at # 3 point
# The w is adjusted to [470, 412]
# Redoing the normal perceptron
# 现在我们有 76 次违例
# 16.0
# No violation happens
# 现在我们有 76 次违例
# 16.0
# Violation time # 77,The distance violation happens at # 1 point
# The w is adjusted to [439, 459]
# Redoing the normal perceptron
# 现在我们有 77 次违例
# 16.0
# No violation happens
# 现在我们有 77 次违例
# 16.0
# Violation time # 78,The distance violation happens at # 3 point
# The w is adjusted to [477, 431]
# Redoing the normal perceptron
# 现在我们有 78 次违例
# 16.0
# No violation happens
# 现在我们有 78 次违例
# 16.0
# Violation time # 79,The distance violation happens at # 4 point
# The w is adjusted to [443, 477]
# Redoing the normal perceptron
# 现在我们有 79 次违例
# 16.0
# No violation happens
# 现在我们有 79 次违例
# 16.0
# Violation time # 80,The distance violation happens at # 3 point
# The w is adjusted to [481, 449]
# Redoing the normal perceptron
# 现在我们有 80 次违例
# 16.0
# No violation happens
# 现在我们有 80 次违例
# 16.0
# Violation time # 81,The distance violation happens at # 4 point
# The w is adjusted to [447, 495]
# Redoing the normal perceptron
# 现在我们有 81 次违例
# 16.0
# No violation happens
# 现在我们有 81 次违例
# 16.0
# Violation time # 82,The distance violation happens at # 3 point
# The w is adjusted to [485, 467]
# Redoing the normal perceptron
# 现在我们有 82 次违例
# 16.0
# No violation happens
# 现在我们有 82 次违例
# 16.0
# Violation time # 83,The distance violation happens at # 3 point
# The w is adjusted to [523, 439]
# Redoing the normal perceptron
# 现在我们有 83 次违例
# 16.0
# No violation happens
# 现在我们有 83 次违例
# 16.0
# Violation time # 84,The distance violation happens at # 1 point
# The w is adjusted to [492, 486]
# Redoing the normal perceptron
# 现在我们有 84 次违例
# 16.0
# No violation happens
# 现在我们有 84 次违例
# 16.0
# Violation time # 85,The distance violation happens at # 3 point
# The w is adjusted to [530, 458]
# Redoing the normal perceptron
# 现在我们有 85 次违例
# 16.0
# No violation happens
# 现在我们有 85 次违例
# 16.0
# Violation time # 86,The distance violation happens at # 1 point
# The w is adjusted to [499, 505]
# Redoing the normal perceptron
# 现在我们有 86 次违例
# 16.0
# No violation happens
# 现在我们有 86 次违例
# 16.0
# Violation time # 87,The distance violation happens at # 3 point
# The w is adjusted to [537, 477]
# Redoing the normal perceptron
# 现在我们有 87 次违例
# 16.0
# No violation happens
# 现在我们有 87 次违例
# 16.0
# Violation time # 88,The distance violation happens at # 4 point
# The w is adjusted to [503, 523]
# Redoing the normal perceptron
# 现在我们有 88 次违例
# 16.0
# No violation happens
# 现在我们有 88 次违例
# 16.0
# Violation time # 89,The distance violation happens at # 3 point
# The w is adjusted to [541, 495]
# Redoing the normal perceptron
# 现在我们有 89 次违例
# 16.0
# No violation happens
# 现在我们有 89 次违例
# 16.0
# Violation time # 90,The distance violation happens at # 4 point
# The w is adjusted to [507, 541]
# Redoing the normal perceptron
# 现在我们有 90 次违例
# 16.0
# No violation happens
# 现在我们有 90 次违例
# 16.0
# Violation time # 91,The distance violation happens at # 3 point
# The w is adjusted to [545, 513]
# Redoing the normal perceptron
# 现在我们有 91 次违例
# 16.0
# No violation happens
# 现在我们有 91 次违例
# 16.0
# Violation time # 92,The distance violation happens at # 4 point
# The w is adjusted to [511, 559]
# Redoing the normal perceptron
# 现在我们有 92 次违例
# 16.0
# No violation happens
# 现在我们有 92 次违例
# 16.0
# Violation time # 93,The distance violation happens at # 3 point
# The w is adjusted to [549, 531]
# Redoing the normal perceptron
# 现在我们有 93 次违例
# 16.0
# No violation happens
# 现在我们有 93 次违例
# 16.0
# Violation time # 94,The distance violation happens at # 3 point
# The w is adjusted to [587, 503]
# Redoing the normal perceptron
# 现在我们有 94 次违例
# 16.0
# No violation happens
# 现在我们有 94 次违例
# 16.0
# Violation time # 95,The distance violation happens at # 1 point
# The w is adjusted to [556, 550]
# Redoing the normal perceptron
# 现在我们有 95 次违例
# 16.0
# No violation happens
# 现在我们有 95 次违例
# 16.0
# Violation time # 96,The distance violation happens at # 3 point
# The w is adjusted to [594, 522]
# Redoing the normal perceptron
# 现在我们有 96 次违例
# 16.0
# No violation happens
# 现在我们有 96 次违例
# 16.0
# Violation time # 97,The distance violation happens at # 1 point
# The w is adjusted to [563, 569]
# Redoing the normal perceptron
# 现在我们有 97 次违例
# 16.0
# No violation happens
# 现在我们有 97 次违例
# 16.0
# Violation time # 98,The distance violation happens at # 3 point
# The w is adjusted to [601, 541]
# Redoing the normal perceptron
# 现在我们有 98 次违例
# 16.0
# No violation happens
# 现在我们有 98 次违例
# 16.0
# Violation time # 99,The distance violation happens at # 4 point
# The w is adjusted to [567, 587]
# Redoing the normal perceptron
# 现在我们有 99 次违例
# 16.0
# No violation happens
# 现在我们有 99 次违例
# 16.0
# Violation time # 100,The distance violation happens at # 3 point
# The w is adjusted to [605, 559]
# Redoing the normal perceptron
# 现在我们有 100 次违例
# 16.0
# No violation happens
# 现在我们有 100 次违例
# 16.0
# Violation time # 101,The distance violation happens at # 4 point
# The w is adjusted to [571, 605]
# Redoing the normal perceptron
# 现在我们有 101 次违例
# 16.0
# No violation happens
# 现在我们有 101 次违例
# 16.0
# Violation time # 102,The distance violation happens at # 3 point
# The w is adjusted to [609, 577]
# Redoing the normal perceptron
# 现在我们有 102 次违例
# 16.0
# No violation happens
# 现在我们有 102 次违例
# 16.0
# Violation time # 103,The distance violation happens at # 4 point
# The w is adjusted to [575, 623]
# Redoing the normal perceptron
# 现在我们有 103 次违例
# 16.0
# No violation happens
# 现在我们有 103 次违例
# 16.0
# Violation time # 104,The distance violation happens at # 3 point
# The w is adjusted to [613, 595]
# Redoing the normal perceptron
# 现在我们有 104 次违例
# 16.0
# No violation happens
# 现在我们有 104 次违例
# 16.0
# Violation time # 105,The distance violation happens at # 3 point
# The w is adjusted to [651, 567]
# Redoing the normal perceptron
# 现在我们有 105 次违例
# 16.0
# No violation happens
# 现在我们有 105 次违例
# 16.0
# Violation time # 106,The distance violation happens at # 1 point
# The w is adjusted to [620, 614]
# Redoing the normal perceptron
# 现在我们有 106 次违例
# 16.0
# No violation happens
# 现在我们有 106 次违例
# 16.0
# Violation time # 107,The distance violation happens at # 3 point
# The w is adjusted to [658, 586]
# Redoing the normal perceptron
# 现在我们有 107 次违例
# 16.0
# No violation happens
# 现在我们有 107 次违例
# 16.0
# Violation time # 108,The distance violation happens at # 4 point
# The w is adjusted to [624, 632]
# Redoing the normal perceptron
# 现在我们有 108 次违例
# 16.0
# No violation happens
# 现在我们有 108 次违例
# 16.0
# Violation time # 109,The distance violation happens at # 3 point
# The w is adjusted to [662, 604]
# Redoing the normal perceptron
# 现在我们有 109 次违例
# 16.0
# No violation happens
# 现在我们有 109 次违例
# 16.0
# Violation time # 110,The distance violation happens at # 4 point
# The w is adjusted to [628, 650]
# Redoing the normal perceptron
# 现在我们有 110 次违例
# 16.0
# No violation happens
# 现在我们有 110 次违例
# 16.0
# Violation time # 111,The distance violation happens at # 3 point
# The w is adjusted to [666, 622]
# Redoing the normal perceptron
# 现在我们有 111 次违例
# 16.0
# No violation happens
# 现在我们有 111 次违例
# 16.0
# Violation time # 112,The distance violation happens at # 4 point
# The w is adjusted to [632, 668]
# Redoing the normal perceptron
# 现在我们有 112 次违例
# 16.0
# No violation happens
# 现在我们有 112 次违例
# 16.0
# Violation time # 113,The distance violation happens at # 3 point
# The w is adjusted to [670, 640]
# Redoing the normal perceptron
# 现在我们有 113 次违例
# 16.0
# No violation happens
# 现在我们有 113 次违例
# 16.0
# Violation time # 114,The distance violation happens at # 4 point
# The w is adjusted to [636, 686]
# Redoing the normal perceptron
# 现在我们有 114 次违例
# 16.0
# No violation happens
# 现在我们有 114 次违例
# 16.0
# Violation time # 115,The distance violation happens at # 3 point
# The w is adjusted to [674, 658]
# Redoing the normal perceptron
# 现在我们有 115 次违例
# 16.0
# No violation happens
# 现在我们有 115 次违例
# 16.0
# Violation time # 116,The distance violation happens at # 3 point
# The w is adjusted to [712, 630]
# Redoing the normal perceptron
# 现在我们有 116 次违例
# 16.0
# No violation happens
# 现在我们有 116 次违例
# 16.0
# Violation time # 117,The distance violation happens at # 1 point
# The w is adjusted to [681, 677]
# Redoing the normal perceptron
# 现在我们有 117 次违例
# 16.0
# No violation happens
# 现在我们有 117 次违例
# 16.0
# Violation time # 118,The distance violation happens at # 3 point
# The w is adjusted to [719, 649]
# Redoing the normal perceptron
# 现在我们有 118 次违例
# 16.0
# No violation happens
# 现在我们有 118 次违例
# 16.0
# Violation time # 119,The distance violation happens at # 4 point
# The w is adjusted to [685, 695]
# Redoing the normal perceptron
# 现在我们有 119 次违例
# 16.0
# No violation happens
# 现在我们有 119 次违例
# 16.0
# Violation time # 120,The distance violation happens at # 3 point
# The w is adjusted to [723, 667]
# Redoing the normal perceptron
# 现在我们有 120 次违例
# 16.0
# No violation happens
# 现在我们有 120 次违例
# 16.0
# Violation time # 121,The distance violation happens at # 4 point
# The w is adjusted to [689, 713]
# Redoing the normal perceptron
# 现在我们有 121 次违例
# 16.0
# No violation happens
# 现在我们有 121 次违例
# 16.0
# Violation time # 122,The distance violation happens at # 3 point
# The w is adjusted to [727, 685]
# Redoing the normal perceptron
# 现在我们有 122 次违例
# 16.0
# No violation happens
# 现在我们有 122 次违例
# 16.0
# Violation time # 123,The distance violation happens at # 4 point
# The w is adjusted to [693, 731]
# Redoing the normal perceptron
# 现在我们有 123 次违例
# 16.0
# No violation happens
# 现在我们有 123 次违例
# 16.0
# Violation time # 124,The distance violation happens at # 3 point
# The w is adjusted to [731, 703]
# Redoing the normal perceptron
# 现在我们有 124 次违例
# 16.0
# No violation happens
# 现在我们有 124 次违例
# 16.0
# Violation time # 125,The distance violation happens at # 3 point
# The w is adjusted to [769, 675]
# Redoing the normal perceptron
# 现在我们有 125 次违例
# 16.0
# No violation happens
# 现在我们有 125 次违例
# 16.0
# Violation time # 126,The distance violation happens at # 1 point
# The w is adjusted to [738, 722]
# Redoing the normal perceptron
# 现在我们有 126 次违例
# 16.0
# No violation happens
# 现在我们有 126 次违例
# 16.0
# Violation time # 127,The distance violation happens at # 3 point
# The w is adjusted to [776, 694]
# Redoing the normal perceptron
# 现在我们有 127 次违例
# 16.0
# No violation happens
# 现在我们有 127 次违例
# 16.0
# Violation time # 128,The distance violation happens at # 4 point
# The w is adjusted to [742, 740]
# Redoing the normal perceptron
# 现在我们有 128 次违例
# 16.0
# No violation happens
# 现在我们有 128 次违例
# 16.0
# Violation time # 129,The distance violation happens at # 3 point
# The w is adjusted to [780, 712]
# Redoing the normal perceptron
# 现在我们有 129 次违例
# 16.0
# No violation happens
# 现在我们有 129 次违例
# 16.0
# Violation time # 130,The distance violation happens at # 4 point
# The w is adjusted to [746, 758]
# Redoing the normal perceptron
# 现在我们有 130 次违例
# 16.0
# No violation happens
# 现在我们有 130 次违例
# 16.0
# Violation time # 131,The distance violation happens at # 3 point
# The w is adjusted to [784, 730]
# Redoing the normal perceptron
# 现在我们有 131 次违例
# 16.0
# No violation happens
# 现在我们有 131 次违例
# 16.0
# Violation time # 132,The distance violation happens at # 4 point
# The w is adjusted to [750, 776]
# Redoing the normal perceptron
# 现在我们有 132 次违例
# 16.0
# No violation happens
# 现在我们有 132 次违例
# 16.0
# Violation time # 133,The distance violation happens at # 3 point
# The w is adjusted to [788, 748]
# Redoing the normal perceptron
# 现在我们有 133 次违例
# 16.0
# No violation happens
# 现在我们有 133 次违例
# 16.0
# Violation time # 134,The distance violation happens at # 4 point
# The w is adjusted to [754, 794]
# Redoing the normal perceptron
# 现在我们有 134 次违例
# 16.0
# No violation happens
# 现在我们有 134 次违例
# 16.0
# Violation time # 135,The distance violation happens at # 3 point
# The w is adjusted to [792, 766]
# Redoing the normal perceptron
# 现在我们有 135 次违例
# 16.0
# No violation happens
# 现在我们有 135 次违例
# 16.0
# Violation time # 136,The distance violation happens at # 3 point
# The w is adjusted to [830, 738]
# Redoing the normal perceptron
# 现在我们有 136 次违例
# 16.0
# No violation happens
# 现在我们有 136 次违例
# 16.0
# Violation time # 137,The distance violation happens at # 4 point
# The w is adjusted to [796, 784]
# Redoing the normal perceptron
# 现在我们有 137 次违例
# 16.0
# No violation happens
# 现在我们有 137 次违例
# 16.0
# Violation time # 138,The distance violation happens at # 3 point
# The w is adjusted to [834, 756]
# Redoing the normal perceptron
# 现在我们有 138 次违例
# 16.0
# No violation happens
# 现在我们有 138 次违例
# 16.0
# Violation time # 139,The distance violation happens at # 4 point
# The w is adjusted to [800, 802]
# Redoing the normal perceptron
# 现在我们有 139 次违例
# 16.0
# No violation happens
# 现在我们有 139 次违例
# 16.0
# Violation time # 140,The distance violation happens at # 3 point
# The w is adjusted to [838, 774]
# Redoing the normal perceptron
# 现在我们有 140 次违例
# 16.0
# No violation happens
# 现在我们有 140 次违例
# 16.0
# Violation time # 141,The distance violation happens at # 4 point
# The w is adjusted to [804, 820]
# Redoing the normal perceptron
# 现在我们有 141 次违例
# 16.0
# No violation happens
# 现在我们有 141 次违例
# 16.0
# Violation time # 142,The distance violation happens at # 3 point
# The w is adjusted to [842, 792]
# Redoing the normal perceptron
# 现在我们有 142 次违例
# 16.0
# No violation happens
# 现在我们有 142 次违例
# 16.0
# Violation time # 143,The distance violation happens at # 4 point
# The w is adjusted to [808, 838]
# Redoing the normal perceptron
# 现在我们有 143 次违例
# 16.0
# No violation happens
# 现在我们有 143 次违例
# 16.0
# Violation time # 144,The distance violation happens at # 3 point
# The w is adjusted to [846, 810]
# Redoing the normal perceptron
# 现在我们有 144 次违例
# 16.0
# No violation happens
# 现在我们有 144 次违例
# 16.0
# Violation time # 145,The distance violation happens at # 4 point
# The w is adjusted to [812, 856]
# Redoing the normal perceptron
# 现在我们有 145 次违例
# 16.0
# No violation happens
# 现在我们有 145 次违例
# 16.0
# Violation time # 146,The distance violation happens at # 3 point
# The w is adjusted to [850, 828]
# Redoing the normal perceptron
# 现在我们有 146 次违例
# 16.0
# No violation happens
# 现在我们有 146 次违例
# 16.0
# Violation time # 147,The distance violation happens at # 3 point
# The w is adjusted to [888, 800]
# Redoing the normal perceptron
# 现在我们有 147 次违例
# 16.0
# No violation happens
# 现在我们有 147 次违例
# 16.0
# Violation time # 148,The distance violation happens at # 4 point
# The w is adjusted to [854, 846]
# Redoing the normal perceptron
# 现在我们有 148 次违例
# 16.0
# No violation happens
# 现在我们有 148 次违例
# 16.0
# Violation time # 149,The distance violation happens at # 3 point
# The w is adjusted to [892, 818]
# Redoing the normal perceptron
# 现在我们有 149 次违例
# 16.0
# No violation happens
# 现在我们有 149 次违例
# 16.0
# Violation time # 150,The distance violation happens at # 4 point
# The w is adjusted to [858, 864]
# Redoing the normal perceptron
# 现在我们有 150 次违例
# 16.0
# No violation happens
# 现在我们有 150 次违例
# 16.0
# Violation time # 151,The distance violation happens at # 3 point
# The w is adjusted to [896, 836]
# Redoing the normal perceptron
# 现在我们有 151 次违例
# 16.0
# No violation happens
# 现在我们有 151 次违例
# 16.0
# Violation time # 152,The distance violation happens at # 4 point
# The w is adjusted to [862, 882]
# Redoing the normal perceptron
# 现在我们有 152 次违例
# 16.0
# No violation happens
# 现在我们有 152 次违例
# 16.0
# Violation time # 153,The distance violation happens at # 3 point
# The w is adjusted to [900, 854]
# Redoing the normal perceptron
# 现在我们有 153 次违例
# 16.0
# No violation happens
# 现在我们有 153 次违例
# 16.0
# Violation time # 154,The distance violation happens at # 4 point
# The w is adjusted to [866, 900]
# Redoing the normal perceptron
# 现在我们有 154 次违例
# 16.0
# No violation happens
# 现在我们有 154 次违例
# 16.0
# Violation time # 155,The distance violation happens at # 3 point
# The w is adjusted to [904, 872]
# Redoing the normal perceptron
# 现在我们有 155 次违例
# 16.0
# No violation happens
# 现在我们有 155 次违例
# 16.0
# Violation time # 156,The distance violation happens at # 3 point
# The w is adjusted to [942, 844]
# Redoing the normal perceptron
# 现在我们有 156 次违例
# 16.0
# No violation happens
# 现在我们有 156 次违例
# 16.0
# Violation time # 157,The distance violation happens at # 4 point
# The w is adjusted to [908, 890]
# Redoing the normal perceptron
# 现在我们有 157 次违例
# 16.0
# No violation happens
# 现在我们有 157 次违例
# 16.0
# Violation time # 158,The distance violation happens at # 3 point
# The w is adjusted to [946, 862]
# Redoing the normal perceptron
# 现在我们有 158 次违例
# 16.0
# No violation happens
# 现在我们有 158 次违例
# 16.0
# Violation time # 159,The distance violation happens at # 4 point
# The w is adjusted to [912, 908]
# Redoing the normal perceptron
# 现在我们有 159 次违例
# 16.0
# No violation happens
# 现在我们有 159 次违例
# 16.0
# Violation time # 160,The distance violation happens at # 3 point
# The w is adjusted to [950, 880]
# Redoing the normal perceptron
# 现在我们有 160 次违例
# 16.0
# No violation happens
# 现在我们有 160 次违例
# 16.0
# Violation time # 161,The distance violation happens at # 4 point
# The w is adjusted to [916, 926]
# Redoing the normal perceptron
# 现在我们有 161 次违例
# 16.0
# No violation happens
# 现在我们有 161 次违例
# 16.0
# Violation time # 162,The distance violation happens at # 3 point
# The w is adjusted to [954, 898]
# Redoing the normal perceptron
# 现在我们有 162 次违例
# 16.0
# No violation happens
# 现在我们有 162 次违例
# 16.0
# Violation time # 163,The distance violation happens at # 4 point
# The w is adjusted to [920, 944]
# Redoing the normal perceptron
# 现在我们有 163 次违例
# 16.0
# No violation happens
# 现在我们有 163 次违例
# 16.0
# Violation time # 164,The distance violation happens at # 3 point
# The w is adjusted to [958, 916]
# Redoing the normal perceptron
# 现在我们有 164 次违例
# 16.0
# No violation happens
# 现在我们有 164 次违例
# 16.0
# Violation time # 165,The distance violation happens at # 4 point
# The w is adjusted to [924, 962]
# Redoing the normal perceptron
# 现在我们有 165 次违例
# 16.0
# No violation happens
# 现在我们有 165 次违例
# 16.0
# Violation time # 166,The distance violation happens at # 3 point
# The w is adjusted to [962, 934]
# Redoing the normal perceptron
# 现在我们有 166 次违例
# 16.0
# No violation happens
# 现在我们有 166 次违例
# 16.0
# Violation time # 167,The distance violation happens at # 3 point
# The w is adjusted to [1000, 906]
# Redoing the normal perceptron
# 现在我们有 167 次违例
# 16.0
# No violation happens
# 现在我们有 167 次违例
# 16.0
# Violation time # 168,The distance violation happens at # 4 point
# The w is adjusted to [966, 952]
# Redoing the normal perceptron
# 现在我们有 168 次违例
# 16.0
# No violation happens
# 现在我们有 168 次违例
# 16.0
# Violation time # 169,The distance violation happens at # 3 point
# The w is adjusted to [1004, 924]
# Redoing the normal perceptron
# 现在我们有 169 次违例
# 16.0
# No violation happens
# 现在我们有 169 次违例
# 16.0
# Violation time # 170,The distance violation happens at # 4 point
# The w is adjusted to [970, 970]
# Redoing the normal perceptron
# 现在我们有 170 次违例
# 16.0
# No violation happens
# 现在我们有 170 次违例
# 16.0
# Violation time # 171,The distance violation happens at # 3 point
# The w is adjusted to [1008, 942]
# Redoing the normal perceptron
# 现在我们有 171 次违例
# 16.0
# No violation happens
# 现在我们有 171 次违例
# 16.0
# Violation time # 172,The distance violation happens at # 4 point
# The w is adjusted to [974, 988]
# Redoing the normal perceptron
# 现在我们有 172 次违例
# 16.0
# No violation happens
# 现在我们有 172 次违例
# 16.0
# Violation time # 173,The distance violation happens at # 3 point
# The w is adjusted to [1012, 960]
# Redoing the normal perceptron
# 现在我们有 173 次违例
# 16.0
# No violation happens
# 现在我们有 173 次违例
# 16.0
# Violation time # 174,The distance violation happens at # 4 point
# The w is adjusted to [978, 1006]
# Redoing the normal perceptron
# 现在我们有 174 次违例
# 16.0
# No violation happens
# 现在我们有 174 次违例
# 16.0
# Violation time # 175,The distance violation happens at # 3 point
# The w is adjusted to [1016, 978]
# Redoing the normal perceptron
# 现在我们有 175 次违例
# 16.0
# No violation happens
# 现在我们有 175 次违例
# 16.0
# Violation time # 176,The distance violation happens at # 3 point
# The w is adjusted to [1054, 950]
# Redoing the normal perceptron
# 现在我们有 176 次违例
# 16.0
# No violation happens
# 现在我们有 176 次违例
# 16.0
# Violation time # 177,The distance violation happens at # 4 point
# The w is adjusted to [1020, 996]
# Redoing the normal perceptron
# 现在我们有 177 次违例
# 16.0
# No violation happens
# 现在我们有 177 次违例
# 16.0
# Violation time # 178,The distance violation happens at # 3 point
# The w is adjusted to [1058, 968]
# Redoing the normal perceptron
# 现在我们有 178 次违例
# 16.0
# No violation happens
# 现在我们有 178 次违例
# 16.0
# Violation time # 179,The distance violation happens at # 4 point
# The w is adjusted to [1024, 1014]
# Redoing the normal perceptron
# 现在我们有 179 次违例
# 16.0
# No violation happens
# 现在我们有 179 次违例
# 16.0
# Violation time # 180,The distance violation happens at # 3 point
# The w is adjusted to [1062, 986]
# Redoing the normal perceptron
# 现在我们有 180 次违例
# 16.0
# No violation happens
# 现在我们有 180 次违例
# 16.0
# Violation time # 181,The distance violation happens at # 4 point
# The w is adjusted to [1028, 1032]
# Redoing the normal perceptron
# 现在我们有 181 次违例
# 16.0
# No violation happens
# 现在我们有 181 次违例
# 16.0
# Violation time # 182,The distance violation happens at # 3 point
# The w is adjusted to [1066, 1004]
# Redoing the normal perceptron
# 现在我们有 182 次违例
# 16.0
# No violation happens
# 现在我们有 182 次违例
# 16.0
# Violation time # 183,The distance violation happens at # 4 point
# The w is adjusted to [1032, 1050]
# Redoing the normal perceptron
# 现在我们有 183 次违例
# 16.0
# No violation happens
# 现在我们有 183 次违例
# 16.0
# Violation time # 184,The distance violation happens at # 3 point
# The w is adjusted to [1070, 1022]
# Redoing the normal perceptron
# 现在我们有 184 次违例
# 16.0
# No violation happens
# 现在我们有 184 次违例
# 16.0
# Violation time # 185,The distance violation happens at # 4 point
# The w is adjusted to [1036, 1068]
# Redoing the normal perceptron
# 现在我们有 185 次违例
# 16.0
# No violation happens
# 现在我们有 185 次违例
# 16.0
# Violation time # 186,The distance violation happens at # 3 point
# The w is adjusted to [1074, 1040]
# Redoing the normal perceptron
# 现在我们有 186 次违例
# 16.0
# No violation happens
# 现在我们有 186 次违例
# 16.0
# Violation time # 187,The distance violation happens at # 3 point
# The w is adjusted to [1112, 1012]
# Redoing the normal perceptron
# 现在我们有 187 次违例
# 16.0
# No violation happens
# 现在我们有 187 次违例
# 16.0
# Violation time # 188,The distance violation happens at # 4 point
# The w is adjusted to [1078, 1058]
# Redoing the normal perceptron
# 现在我们有 188 次违例
# 16.0
# No violation happens
# 现在我们有 188 次违例
# 16.0
# Violation time # 189,The distance violation happens at # 3 point
# The w is adjusted to [1116, 1030]
# Redoing the normal perceptron
# 现在我们有 189 次违例
# 16.0
# No violation happens
# 现在我们有 189 次违例
# 16.0
# Violation time # 190,The distance violation happens at # 4 point
# The w is adjusted to [1082, 1076]
# Redoing the normal perceptron
# 现在我们有 190 次违例
# 16.0
# No violation happens
# 现在我们有 190 次违例
# 16.0
# Violation time # 191,The distance violation happens at # 3 point
# The w is adjusted to [1120, 1048]
# Redoing the normal perceptron
# 现在我们有 191 次违例
# 16.0
# No violation happens
# 现在我们有 191 次违例
# 16.0
# Violation time # 192,The distance violation happens at # 4 point
# The w is adjusted to [1086, 1094]
# Redoing the normal perceptron
# 现在我们有 192 次违例
# 16.0
# No violation happens
# 现在我们有 192 次违例
# 16.0
# Violation time # 193,The distance violation happens at # 3 point
# The w is adjusted to [1124, 1066]
# Redoing the normal perceptron
# 现在我们有 193 次违例
# Violation次数超出限制，r_guess减小一倍
# 8.0
# Violation time # 1,The violation happens at # 1 point
# The w is adjusted to [-31, 47]
# 现在我们有 1 次违例
# 8.0
# Violation time # 2,The violation happens at # 3 point
# The w is adjusted to [7, 19]
# 现在我们有 2 次违例
# 8.0
# Violation time # 3,The violation happens at # 3 point
# The w is adjusted to [45, -9]
# 现在我们有 3 次违例
# 8.0
# Violation time # 4,The violation happens at # 1 point
# The w is adjusted to [14, 38]
# 现在我们有 4 次违例
# 8.0
# Violation time # 5,The violation happens at # 3 point
# The w is adjusted to [52, 10]
# 现在我们有 5 次违例
# 8.0
# Violation time # 6,The violation happens at # 1 point
# The w is adjusted to [21, 57]
# 现在我们有 6 次违例
# 8.0
# Violation time # 7,The violation happens at # 3 point
# The w is adjusted to [59, 29]
# 现在我们有 7 次违例
# 8.0
# Violation time # 8,The violation happens at # 1 point
# The w is adjusted to [28, 76]
# 现在我们有 8 次违例
# 8.0
# Violation time # 9,The violation happens at # 3 point
# The w is adjusted to [66, 48]
# 现在我们有 9 次违例
# 8.0
# Violation time # 10,The violation happens at # 4 point
# The w is adjusted to [32, 94]
# 现在我们有 10 次违例
# 8.0
# Violation time # 11,The violation happens at # 3 point
# The w is adjusted to [70, 66]
# 现在我们有 11 次违例
# 8.0
# No violation happens
# 现在我们有 11 次违例
# 8.0
# No distance violation happens
# 现在我们有 11 次违例
# 8.0
# The final w is [70, 66]
# We guarantee the margin to be at least 4.0
# Total violation time is 11

# %%
a = True
while(a == True):
    a = False
    print('test')
# Out:
# test

# %%
w_tmp = [-17643, -3936, -4949]
is_violation = check_violation(points_list[3],w_tmp)
is_violation
# Out:
# True
