# %%
import math

# %%
f = open("data_point.txt", "r")  # 打开文件
    #data = f.read()  # 读取文件
data_format = f.readline()
num_point = int(data_format[0])
num_dim = int(data_format[2])
w = [0]
# 建造w
for i in range(num_dim-1):
    w.append(0)
#查看数据
print(num_point)
print(num_dim)
print(w)
print(w[0]+1)
print(w)
# Out:
# 4
# 2
# [0, 0]
# 1
# [0, 0]

# %%
# 打开文件
#f_tmp = open("data_point.txt", "r") 
f_tmp = open("test_on_git_1.txt", "r") 
#f_tmp = open("new_train_d9.txt", "r") 
data_format = f_tmp.readline()
# 读数据格式
data_format = data_format.split(' ')
num_point = int(data_format[0])
num_dim = int(data_format[1])
w = [0]
# 建造w
for i in range(num_dim-1):
    w.append(0)
# 建造空数据集
points_list = []
# 建造数据集
points = f_tmp.readlines()
for i in points:
    points_list.append(i.split())
points_list
# Out:
# [['-7682', '-7495', '170', '1'],
#  ['-239', '-4815', '3638', '1'],
#  ['-9722', '8374', '-8757', '1'],
#  ['9353', '-2869', '8687', '1'],
#  ['5102', '-4379', '6675', '1'],
#  ['-8773', '2386', '-3433', '1'],
#  ['8789', '4187', '9380', '1'],
#  ['2782', '-298', '6519', '1'],
#  ['-4856', '-3418', '740', '1'],
#  ['-6840', '2427', '7945', '1'],
#  ['3981', '7849', '-2771', '0'],
#  ['6928', '4774', '-2686', '0'],
#  ['7168', '-8994', '2941', '0'],
#  ['8870', '527', '3969', '0'],
#  ['-8073', '-215', '-5881', '0'],
#  ['-3048', '-8445', '40', '0'],
#  ['8512', '-1730', '-5727', '0'],
#  ['1369', '-6755', '-3257', '0'],
#  ['-3639', '6134', '-6578', '0'],
#  ['6378', '-9436', '661', '0']]

# %%
num_point,num_dim
# Out:
# (20, 3)

# %%
def list_str_to_int(points_list):
    for i in range(len(points_list)):
        for j in range(len(points_list[0])):
            points_list[i][j] = int(points_list[i][j])

# %%
list_str_to_int(points_list)
points_list
# Out:
# [[-7682, -7495, 170, 1],
#  [-239, -4815, 3638, 1],
#  [-9722, 8374, -8757, 1],
#  [9353, -2869, 8687, 1],
#  [5102, -4379, 6675, 1],
#  [-8773, 2386, -3433, 1],
#  [8789, 4187, 9380, 1],
#  [2782, -298, 6519, 1],
#  [-4856, -3418, 740, 1],
#  [-6840, 2427, 7945, 1],
#  [3981, 7849, -2771, 0],
#  [6928, 4774, -2686, 0],
#  [7168, -8994, 2941, 0],
#  [8870, 527, 3969, 0],
#  [-8073, -215, -5881, 0],
#  [-3048, -8445, 40, 0],
#  [8512, -1730, -5727, 0],
#  [1369, -6755, -3257, 0],
#  [-3639, 6134, -6578, 0],
#  [6378, -9436, 661, 0]]

# %%
def point_multiply(point1,w):
    counts = 0
    for index in range(num_dim):
        counts = counts + point1[index]* w[index]
    return counts

# %%
tmp_counts = point_multiply(points_list[0],w)
tmp_counts
# Out:
# 0

# %%
# 违反返回true,不违反返回false
def check_violation(point1,w):
    sum_result = point_multiply(point1,w)
    # 标签为 1 时
    if points_list[num_dim] == 1:
        if sum_result <= 0:
            return True
        else:
            return False
    # 标签为 0 时
    else:
        if sum_result >= 0:
            return True
        else:
            return False

# %%
def perceptron(point_list,w):
    global violation_times
    for point_index in range(len(point_list)):
        is_violation = check_violation(point_list[point_index],w)
        if (is_violation):
            if (point_list[point_index][num_dim] == 1):
                for update_index in range(len(w)):
                    w[update_index] = w[update_index] + point_list[point_index][update_index]
            else:
                for update_index in range(len(w)):
                    w[update_index] = w[update_index] - point_list[point_index][update_index]
            print("Violation time # {},The violation happens at # {} point".format(violation_times+1,point_index+1))
            print("The w is adjusted to {}".format(w))
            violation_times = violation_times + 1
            break
    print("No violation happens ".format(w))
    return True

# %%
perceptron(points_list,w)
# Out:
# No violation happens, the w in stage 1 is [-3, -3]
# True

# %%
is_finish = False
violation_times = 0
while(is_finish == False):
    is_finish = perceptron(points_list,w)
print(violation_times)
# Out:
# Violation time # 1,The violation happens at # 1 point
# The w is adjusted to [-7682, -7495, 170]
# No violation happens
# 1

# %%
def point_square(point):
    R = 0
    for i in range(num_dim):
        R = R + point[i] * point[i]
    return R

# %%
tmp = point_square(w)
tmp
# Out:
# 5

# %%
tmp ** 0.5
# Out:
# 2.23606797749979

# %%
def find_R(points_list):
    tmp_R = 0
    for i in range(num_point):
        this_R = point_square(points_list[i])
        if(this_R > tmp_R):
            tmp_R = this_R
    return tmp_R

# %%
9722**2 + 8374

# %%
biggest_R = find_R(points_list)
biggest_R
# Out:
# 115217049

# %%
biggest_R ** 0.5
# Out:
# 10733.920486010691

# %%
def dis_pt_to_plane(points,w):
    distance = 0
    w_denominator = point_square(w)
    w_denominator = w_denominator ** 0.5
    for i in range(num_dim):
        distance = distance + points[i]*w[i]
    #absolute
    result = abs(distance / w_denominator)
    # round set to 3
    result = round(result,3)
    return result

# %%
dis = dis_pt_to_plane(points_list[0],w)
dis
# Out:
# 2.236

# %%
def check_violation_distance(point,w,r_guess):
    r_guess_half = r_guess / 2
    dist_to_plane = dis_pt_to_plane(point,w)
    if dist_to_plane < r_guess_half :
        return True
    else:
        return False

# %%
def perceptron_distance(points_list,w,r_guess):
    global violation_times
    for i in range(num_point):
        # define a flag
        is_distance_violation = check_violation_distance(points_list[i],w,r_guess)
        # if violation happens
        if(is_distance_violation):
            if (points_list[i][num_dim] == 1):
                for update_index in range(len(w)):
                    w[update_index] = w[update_index] + points_list[i][update_index]
            else:
                for update_index in range(len(w)):
                    w[update_index] = w[update_index] - points_list[i][update_index]
            print("Violation time # {},The distance violation happens at # {} point".format(violation_times+1,i+1))
            print("The w is adjusted to {}".format(w))
            print("Redoing the normal perceptron")
            violation_times = violation_times + 1
            global is_finish_stage1
            is_finish_stage1 = False
            break
    if(is_finish_stage1 == True):
        print("No distance violation happens".format(w))
        return True
    else:
        return False

# %%
def Initiate_w():
    global w
    w = [0]
    for i in range(num_dim-1):
        w.append(0)

# %%
def cal_terminate_time(points_list,r_guess):
    R = find_R(points_list)
    r_guess_tmp = r_guess * r_guess
    return (12*R/r_guess_tmp)

# %%
def Break_perceptron(points_list):
    global is_finish_stage1
    global is_finish_stage2
    global violation_times
    global r_guess
    termi_time = cal_terminate_time(points_list,r_guess)
    print('现在我们有 {} 次违例'.format(violation_times) )
    # 超过终止次数
    if(termi_time < violation_times):
        # 初始化，重新进行下一轮
        is_finish_stage1 = False
        is_finish_stage2 = False
        r_guess = r_guess / 2
        violation_times = 0
        Initiate_w()
        print('Violation次数超出限制，r_guess减小一倍')
    else:
        pass

# %%
# 建造w
w = [0]
for i in range(num_dim-1):
    w.append(0)
is_finish_stage1 = False
is_finish_stage2 = False
r_guess = find_R(points_list)
r_guess = round(r_guess** 0.5)
violation_times = 0
while(is_finish_stage1 == False or is_finish_stage2 == False):
    if(is_finish_stage1 == False and is_finish_stage2 == False):
        is_finish_stage1 = perceptron(points_list,w)
    elif(is_finish_stage1 == True and is_finish_stage2 == False):
        is_finish_stage2 = perceptron_distance(points_list,w,r_guess)
    elif(is_finish_stage1 == False and is_finish_stage2 == True):
        is_finish_stage1 = perceptron(points_list,w)
    #check whether it needs terminate
    Break_perceptron(points_list)
    print(r_guess)
print("The final w is {}".format(w))
print("We guarantee the margin to be at least {}".format(r_guess/2))
print("Total violation time is {}".format(violation_times))
# Out:
# Violation time # 1,The violation happens at # 1 point
# The w is adjusted to [-7682, -7495, 170]
# No violation happens
# 现在我们有 1 次违例
# 15535
# Violation time # 2,The distance violation happens at # 2 point
# The w is adjusted to [-7921, -12310, 3808]
# Redoing the normal perceptron
# 现在我们有 2 次违例
# 15535
# Violation time # 3,The violation happens at # 1 point
# The w is adjusted to [-15603, -19805, 3978]
# No violation happens
# 现在我们有 3 次违例
# 15535
# Violation time # 4,The distance violation happens at # 2 point
# The w is adjusted to [-15842, -24620, 7616]
# Redoing the normal perceptron
# 现在我们有 4 次违例
# 15535
# Violation time # 5,The violation happens at # 1 point
# The w is adjusted to [-23524, -32115, 7786]
# No violation happens
# 现在我们有 5 次违例
# 15535
# Violation time # 6,The distance violation happens at # 2 point
# The w is adjusted to [-23763, -36930, 11424]
# Redoing the normal perceptron
# 现在我们有 6 次违例
# 15535
# Violation time # 7,The violation happens at # 1 point
# The w is adjusted to [-31445, -44425, 11594]
# No violation happens
# 现在我们有 7 次违例
# 15535
# Violation time # 8,The distance violation happens at # 2 point
# The w is adjusted to [-31684, -49240, 15232]
# Redoing the normal perceptron
# 现在我们有 8 次违例
# 15535
# Violation time # 9,The violation happens at # 1 point
# The w is adjusted to [-39366, -56735, 15402]
# No violation happens
# 现在我们有 9 次违例
# 15535
# Violation time # 10,The distance violation happens at # 2 point
# The w is adjusted to [-39605, -61550, 19040]
# Redoing the normal perceptron
# 现在我们有 10 次违例
# 15535
# Violation time # 11,The violation happens at # 1 point
# The w is adjusted to [-47287, -69045, 19210]
# No violation happens
# 现在我们有 11 次违例
# 15535
# Violation time # 12,The distance violation happens at # 2 point
# The w is adjusted to [-47526, -73860, 22848]
# Redoing the normal perceptron
# 现在我们有 12 次违例
# Violation次数超出限制，r_guess减小一倍
# 7767.5
# Violation time # 1,The violation happens at # 1 point
# The w is adjusted to [-7682, -7495, 170]
# No violation happens
# 现在我们有 1 次违例
# 7767.5
# Violation time # 2,The distance violation happens at # 2 point
# The w is adjusted to [-7921, -12310, 3808]
# Redoing the normal perceptron
# 现在我们有 2 次违例
# 7767.5
# Violation time # 3,The violation happens at # 1 point
# The w is adjusted to [-15603, -19805, 3978]
# No violation happens
# 现在我们有 3 次违例
# 7767.5
# Violation time # 4,The distance violation happens at # 3 point
# The w is adjusted to [-25325, -11431, -4779]
# Redoing the normal perceptron
# 现在我们有 4 次违例
# 7767.5
# Violation time # 5,The violation happens at # 1 point
# The w is adjusted to [-33007, -18926, -4609]
# No violation happens
# 现在我们有 5 次违例
# 7767.5
# Violation time # 6,The distance violation happens at # 2 point
# The w is adjusted to [-33246, -23741, -971]
# Redoing the normal perceptron
# 现在我们有 6 次违例
# 7767.5
# Violation time # 7,The violation happens at # 1 point
# The w is adjusted to [-40928, -31236, -801]
# No violation happens
# 现在我们有 7 次违例
# 7767.5
# Violation time # 8,The distance violation happens at # 2 point
# The w is adjusted to [-41167, -36051, 2837]
# Redoing the normal perceptron
# 现在我们有 8 次违例
# 7767.5
# Violation time # 9,The violation happens at # 1 point
# The w is adjusted to [-48849, -43546, 3007]
# No violation happens
# 现在我们有 9 次违例
# 7767.5
# Violation time # 10,The distance violation happens at # 2 point
# The w is adjusted to [-49088, -48361, 6645]
# Redoing the normal perceptron
# 现在我们有 10 次违例
# 7767.5
# Violation time # 11,The violation happens at # 1 point
# The w is adjusted to [-56770, -55856, 6815]
# No violation happens
# 现在我们有 11 次违例
# 7767.5
# Violation time # 12,The distance violation happens at # 2 point
# The w is adjusted to [-57009, -60671, 10453]
# Redoing the normal perceptron
# 现在我们有 12 次违例
# 7767.5
# Violation time # 13,The violation happens at # 1 point
# The w is adjusted to [-64691, -68166, 10623]
# No violation happens
# 现在我们有 13 次违例
# 7767.5
# Violation time # 14,The distance violation happens at # 3 point
# The w is adjusted to [-74413, -59792, 1866]
# Redoing the normal perceptron
# 现在我们有 14 次违例
# 7767.5
# Violation time # 15,The violation happens at # 1 point
# The w is adjusted to [-82095, -67287, 2036]
# No violation happens
# 现在我们有 15 次违例
# 7767.5
# Violation time # 16,The distance violation happens at # 2 point
# The w is adjusted to [-82334, -72102, 5674]
# Redoing the normal perceptron
# 现在我们有 16 次违例
# 7767.5
# Violation time # 17,The violation happens at # 1 point
# The w is adjusted to [-90016, -79597, 5844]
# No violation happens
# 现在我们有 17 次违例
# 7767.5
# Violation time # 18,The distance violation happens at # 2 point
# The w is adjusted to [-90255, -84412, 9482]
# Redoing the normal perceptron
# 现在我们有 18 次违例
# 7767.5
# Violation time # 19,The violation happens at # 1 point
# The w is adjusted to [-97937, -91907, 9652]
# No violation happens
# 现在我们有 19 次违例
# 7767.5
# Violation time # 20,The distance violation happens at # 2 point
# The w is adjusted to [-98176, -96722, 13290]
# Redoing the normal perceptron
# 现在我们有 20 次违例
# 7767.5
# Violation time # 21,The violation happens at # 1 point
# The w is adjusted to [-105858, -104217, 13460]
# No violation happens
# 现在我们有 21 次违例
# 7767.5
# Violation time # 22,The distance violation happens at # 2 point
# The w is adjusted to [-106097, -109032, 17098]
# Redoing the normal perceptron
# 现在我们有 22 次违例
# 7767.5
# Violation time # 23,The violation happens at # 1 point
# The w is adjusted to [-113779, -116527, 17268]
# No violation happens
# 现在我们有 23 次违例
# 7767.5
# Violation time # 24,The distance violation happens at # 3 point
# The w is adjusted to [-123501, -108153, 8511]
# Redoing the normal perceptron
# 现在我们有 24 次违例
# 7767.5
# Violation time # 25,The violation happens at # 1 point
# The w is adjusted to [-131183, -115648, 8681]
# No violation happens
# 现在我们有 25 次违例
# 7767.5
# Violation time # 26,The distance violation happens at # 2 point
# The w is adjusted to [-131422, -120463, 12319]
# Redoing the normal perceptron
# 现在我们有 26 次违例
# 7767.5
# Violation time # 27,The violation happens at # 1 point
# The w is adjusted to [-139104, -127958, 12489]
# No violation happens
# 现在我们有 27 次违例
# 7767.5
# Violation time # 28,The distance violation happens at # 2 point
# The w is adjusted to [-139343, -132773, 16127]
# Redoing the normal perceptron
# 现在我们有 28 次违例
# 7767.5
# Violation time # 29,The violation happens at # 1 point
# The w is adjusted to [-147025, -140268, 16297]
# No violation happens
# 现在我们有 29 次违例
# 7767.5
# Violation time # 30,The distance violation happens at # 2 point
# The w is adjusted to [-147264, -145083, 19935]
# Redoing the normal perceptron
# 现在我们有 30 次违例
# 7767.5
# Violation time # 31,The violation happens at # 1 point
# The w is adjusted to [-154946, -152578, 20105]
# No violation happens
# 现在我们有 31 次违例
# 7767.5
# Violation time # 32,The distance violation happens at # 2 point
# The w is adjusted to [-155185, -157393, 23743]
# Redoing the normal perceptron
# 现在我们有 32 次违例
# 7767.5
# Violation time # 33,The violation happens at # 1 point
# The w is adjusted to [-162867, -164888, 23913]
# No violation happens
# 现在我们有 33 次违例
# 7767.5
# Violation time # 34,The distance violation happens at # 3 point
# The w is adjusted to [-172589, -156514, 15156]
# Redoing the normal perceptron
# 现在我们有 34 次违例
# 7767.5
# Violation time # 35,The violation happens at # 1 point
# The w is adjusted to [-180271, -164009, 15326]
# No violation happens
# 现在我们有 35 次违例
# 7767.5
# Violation time # 36,The distance violation happens at # 2 point
# The w is adjusted to [-180510, -168824, 18964]
# Redoing the normal perceptron
# 现在我们有 36 次违例
# 7767.5
# Violation time # 37,The violation happens at # 1 point
# The w is adjusted to [-188192, -176319, 19134]
# No violation happens
# 现在我们有 37 次违例
# 7767.5
# Violation time # 38,The distance violation happens at # 2 point
# The w is adjusted to [-188431, -181134, 22772]
# Redoing the normal perceptron
# 现在我们有 38 次违例
# 7767.5
# Violation time # 39,The violation happens at # 1 point
# The w is adjusted to [-196113, -188629, 22942]
# No violation happens
# 现在我们有 39 次违例
# 7767.5
# Violation time # 40,The distance violation happens at # 2 point
# The w is adjusted to [-196352, -193444, 26580]
# Redoing the normal perceptron
# 现在我们有 40 次违例
# 7767.5
# Violation time # 41,The violation happens at # 1 point
# The w is adjusted to [-204034, -200939, 26750]
# No violation happens
# 现在我们有 41 次违例
# 7767.5
# Violation time # 42,The distance violation happens at # 2 point
# The w is adjusted to [-204273, -205754, 30388]
# Redoing the normal perceptron
# 现在我们有 42 次违例
# 7767.5
# Violation time # 43,The violation happens at # 1 point
# The w is adjusted to [-211955, -213249, 30558]
# No violation happens
# 现在我们有 43 次违例
# 7767.5
# Violation time # 44,The distance violation happens at # 3 point
# The w is adjusted to [-221677, -204875, 21801]
# Redoing the normal perceptron
# 现在我们有 44 次违例
# 7767.5
# Violation time # 45,The violation happens at # 1 point
# The w is adjusted to [-229359, -212370, 21971]
# No violation happens
# 现在我们有 45 次违例
# 7767.5
# Violation time # 46,The distance violation happens at # 2 point
# The w is adjusted to [-229598, -217185, 25609]
# Redoing the normal perceptron
# 现在我们有 46 次违例
# 7767.5
# Violation time # 47,The violation happens at # 1 point
# The w is adjusted to [-237280, -224680, 25779]
# No violation happens
# 现在我们有 47 次违例
# 7767.5
# Violation time # 48,The distance violation happens at # 2 point
# The w is adjusted to [-237519, -229495, 29417]
# Redoing the normal perceptron
# 现在我们有 48 次违例
# Violation次数超出限制，r_guess减小一倍
# 3883.75
# Violation time # 1,The violation happens at # 1 point
# The w is adjusted to [-7682, -7495, 170]
# No violation happens
# 现在我们有 1 次违例
# 3883.75
# Violation time # 2,The distance violation happens at # 3 point
# The w is adjusted to [-17404, 879, -8587]
# Redoing the normal perceptron
# 现在我们有 2 次违例
# 3883.75
# Violation time # 3,The violation happens at # 1 point
# The w is adjusted to [-25086, -6616, -8417]
# No violation happens
# 现在我们有 3 次违例
# 3883.75
# Violation time # 4,The distance violation happens at # 2 point
# The w is adjusted to [-25325, -11431, -4779]
# Redoing the normal perceptron
# 现在我们有 4 次违例
# 3883.75
# Violation time # 5,The violation happens at # 1 point
# The w is adjusted to [-33007, -18926, -4609]
# No violation happens
# 现在我们有 5 次违例
# 3883.75
# Violation time # 6,The distance violation happens at # 19 point
# The w is adjusted to [-29368, -25060, 1969]
# Redoing the normal perceptron
# 现在我们有 6 次违例
# 3883.75
# Violation time # 7,The violation happens at # 1 point
# The w is adjusted to [-37050, -32555, 2139]
# No violation happens
# 现在我们有 7 次违例
# 3883.75
# Violation time # 8,The distance violation happens at # 3 point
# The w is adjusted to [-46772, -24181, -6618]
# Redoing the normal perceptron
# 现在我们有 8 次违例
# 3883.75
# Violation time # 9,The violation happens at # 1 point
# The w is adjusted to [-54454, -31676, -6448]
# No violation happens
# 现在我们有 9 次违例
# 3883.75
# Violation time # 10,The distance violation happens at # 19 point
# The w is adjusted to [-50815, -37810, 130]
# Redoing the normal perceptron
# 现在我们有 10 次违例
# 3883.75
# Violation time # 11,The violation happens at # 1 point
# The w is adjusted to [-58497, -45305, 300]
# No violation happens
# 现在我们有 11 次违例
# 3883.75
# Violation time # 12,The distance violation happens at # 5 point
# The w is adjusted to [-53395, -49684, 6975]
# Redoing the normal perceptron
# 现在我们有 12 次违例
# 3883.75
# Violation time # 13,The violation happens at # 1 point
# The w is adjusted to [-61077, -57179, 7145]
# No violation happens
# 现在我们有 13 次违例
# 3883.75
# Violation time # 14,The distance violation happens at # 3 point
# The w is adjusted to [-70799, -48805, -1612]
# Redoing the normal perceptron
# 现在我们有 14 次违例
# 3883.75
# Violation time # 15,The violation happens at # 1 point
# The w is adjusted to [-78481, -56300, -1442]
# No violation happens
# 现在我们有 15 次违例
# 3883.75
# Violation time # 16,The distance violation happens at # 5 point
# The w is adjusted to [-73379, -60679, 5233]
# Redoing the normal perceptron
# 现在我们有 16 次违例
# 3883.75
# Violation time # 17,The violation happens at # 1 point
# The w is adjusted to [-81061, -68174, 5403]
# No violation happens
# 现在我们有 17 次违例
# 3883.75
# Violation time # 18,The distance violation happens at # 3 point
# The w is adjusted to [-90783, -59800, -3354]
# Redoing the normal perceptron
# 现在我们有 18 次违例
# 3883.75
# Violation time # 19,The violation happens at # 1 point
# The w is adjusted to [-98465, -67295, -3184]
# No violation happens
# 现在我们有 19 次违例
# 3883.75
# Violation time # 20,The distance violation happens at # 5 point
# The w is adjusted to [-93363, -71674, 3491]
# Redoing the normal perceptron
# 现在我们有 20 次违例
# 3883.75
# Violation time # 21,The violation happens at # 1 point
# The w is adjusted to [-101045, -79169, 3661]
# No violation happens
# 现在我们有 21 次违例
# 3883.75
# Violation time # 22,The distance violation happens at # 5 point
# The w is adjusted to [-95943, -83548, 10336]
# Redoing the normal perceptron
# 现在我们有 22 次违例
# 3883.75
# Violation time # 23,The violation happens at # 1 point
# The w is adjusted to [-103625, -91043, 10506]
# No violation happens
# 现在我们有 23 次违例
# 3883.75
# Violation time # 24,The distance violation happens at # 3 point
# The w is adjusted to [-113347, -82669, 1749]
# Redoing the normal perceptron
# 现在我们有 24 次违例
# 3883.75
# Violation time # 25,The violation happens at # 1 point
# The w is adjusted to [-121029, -90164, 1919]
# No violation happens
# 现在我们有 25 次违例
# 3883.75
# Violation time # 26,The distance violation happens at # 5 point
# The w is adjusted to [-115927, -94543, 8594]
# Redoing the normal perceptron
# 现在我们有 26 次违例
# 3883.75
# Violation time # 27,The violation happens at # 1 point
# The w is adjusted to [-123609, -102038, 8764]
# No violation happens
# 现在我们有 27 次违例
# 3883.75
# Violation time # 28,The distance violation happens at # 3 point
# The w is adjusted to [-133331, -93664, 7]
# Redoing the normal perceptron
# 现在我们有 28 次违例
# 3883.75
# Violation time # 29,The violation happens at # 1 point
# The w is adjusted to [-141013, -101159, 177]
# No violation happens
# 现在我们有 29 次违例
# 3883.75
# Violation time # 30,The distance violation happens at # 5 point
# The w is adjusted to [-135911, -105538, 6852]
# Redoing the normal perceptron
# 现在我们有 30 次违例
# 3883.75
# Violation time # 31,The violation happens at # 1 point
# The w is adjusted to [-143593, -113033, 7022]
# No violation happens
# 现在我们有 31 次违例
# 3883.75
# Violation time # 32,The distance violation happens at # 5 point
# The w is adjusted to [-138491, -117412, 13697]
# Redoing the normal perceptron
# 现在我们有 32 次违例
# 3883.75
# Violation time # 33,The violation happens at # 1 point
# The w is adjusted to [-146173, -124907, 13867]
# No violation happens
# 现在我们有 33 次违例
# 3883.75
# Violation time # 34,The distance violation happens at # 3 point
# The w is adjusted to [-155895, -116533, 5110]
# Redoing the normal perceptron
# 现在我们有 34 次违例
# 3883.75
# Violation time # 35,The violation happens at # 1 point
# The w is adjusted to [-163577, -124028, 5280]
# No violation happens
# 现在我们有 35 次违例
# 3883.75
# Violation time # 36,The distance violation happens at # 5 point
# The w is adjusted to [-158475, -128407, 11955]
# Redoing the normal perceptron
# 现在我们有 36 次违例
# 3883.75
# Violation time # 37,The violation happens at # 1 point
# The w is adjusted to [-166157, -135902, 12125]
# No violation happens
# 现在我们有 37 次违例
# 3883.75
# Violation time # 38,The distance violation happens at # 3 point
# The w is adjusted to [-175879, -127528, 3368]
# Redoing the normal perceptron
# 现在我们有 38 次违例
# 3883.75
# Violation time # 39,The violation happens at # 1 point
# The w is adjusted to [-183561, -135023, 3538]
# No violation happens
# 现在我们有 39 次违例
# 3883.75
# Violation time # 40,The distance violation happens at # 5 point
# The w is adjusted to [-178459, -139402, 10213]
# Redoing the normal perceptron
# 现在我们有 40 次违例
# 3883.75
# Violation time # 41,The violation happens at # 1 point
# The w is adjusted to [-186141, -146897, 10383]
# No violation happens
# 现在我们有 41 次违例
# 3883.75
# Violation time # 42,The distance violation happens at # 5 point
# The w is adjusted to [-181039, -151276, 17058]
# Redoing the normal perceptron
# 现在我们有 42 次违例
# 3883.75
# Violation time # 43,The violation happens at # 1 point
# The w is adjusted to [-188721, -158771, 17228]
# No violation happens
# 现在我们有 43 次违例
# 3883.75
# Violation time # 44,The distance violation happens at # 3 point
# The w is adjusted to [-198443, -150397, 8471]
# Redoing the normal perceptron
# 现在我们有 44 次违例
# 3883.75
# Violation time # 45,The violation happens at # 1 point
# The w is adjusted to [-206125, -157892, 8641]
# No violation happens
# 现在我们有 45 次违例
# 3883.75
# Violation time # 46,The distance violation happens at # 5 point
# The w is adjusted to [-201023, -162271, 15316]
# Redoing the normal perceptron
# 现在我们有 46 次违例
# 3883.75
# Violation time # 47,The violation happens at # 1 point
# The w is adjusted to [-208705, -169766, 15486]
# No violation happens
# 现在我们有 47 次违例
# 3883.75
# Violation time # 48,The distance violation happens at # 3 point
# The w is adjusted to [-218427, -161392, 6729]
# Redoing the normal perceptron
# 现在我们有 48 次违例
# 3883.75
# Violation time # 49,The violation happens at # 1 point
# The w is adjusted to [-226109, -168887, 6899]
# No violation happens
# 现在我们有 49 次违例
# 3883.75
# Violation time # 50,The distance violation happens at # 5 point
# The w is adjusted to [-221007, -173266, 13574]
# Redoing the normal perceptron
# 现在我们有 50 次违例
# 3883.75
# Violation time # 51,The violation happens at # 1 point
# The w is adjusted to [-228689, -180761, 13744]
# No violation happens
# 现在我们有 51 次违例
# 3883.75
# Violation time # 52,The distance violation happens at # 5 point
# The w is adjusted to [-223587, -185140, 20419]
# Redoing the normal perceptron
# 现在我们有 52 次违例
# 3883.75
# Violation time # 53,The violation happens at # 1 point
# The w is adjusted to [-231269, -192635, 20589]
# No violation happens
# 现在我们有 53 次违例
# 3883.75
# Violation time # 54,The distance violation happens at # 3 point
# The w is adjusted to [-240991, -184261, 11832]
# Redoing the normal perceptron
# 现在我们有 54 次违例
# 3883.75
# Violation time # 55,The violation happens at # 1 point
# The w is adjusted to [-248673, -191756, 12002]
# No violation happens
# 现在我们有 55 次违例
# 3883.75
# Violation time # 56,The distance violation happens at # 5 point
# The w is adjusted to [-243571, -196135, 18677]
# Redoing the normal perceptron
# 现在我们有 56 次违例
# 3883.75
# Violation time # 57,The violation happens at # 1 point
# The w is adjusted to [-251253, -203630, 18847]
# No violation happens
# 现在我们有 57 次违例
# 3883.75
# Violation time # 58,The distance violation happens at # 3 point
# The w is adjusted to [-260975, -195256, 10090]
# Redoing the normal perceptron
# 现在我们有 58 次违例
# 3883.75
# Violation time # 59,The violation happens at # 1 point
# The w is adjusted to [-268657, -202751, 10260]
# No violation happens
# 现在我们有 59 次违例
# 3883.75
# Violation time # 60,The distance violation happens at # 5 point
# The w is adjusted to [-263555, -207130, 16935]
# Redoing the normal perceptron
# 现在我们有 60 次违例
# 3883.75
# Violation time # 61,The violation happens at # 1 point
# The w is adjusted to [-271237, -214625, 17105]
# No violation happens
# 现在我们有 61 次违例
# 3883.75
# Violation time # 62,The distance violation happens at # 5 point
# The w is adjusted to [-266135, -219004, 23780]
# Redoing the normal perceptron
# 现在我们有 62 次违例
# 3883.75
# Violation time # 63,The violation happens at # 1 point
# The w is adjusted to [-273817, -226499, 23950]
# No violation happens
# 现在我们有 63 次违例
# 3883.75
# Violation time # 64,The distance violation happens at # 3 point
# The w is adjusted to [-283539, -218125, 15193]
# Redoing the normal perceptron
# 现在我们有 64 次违例
# 3883.75
# Violation time # 65,The violation happens at # 1 point
# The w is adjusted to [-291221, -225620, 15363]
# No violation happens
# 现在我们有 65 次违例
# 3883.75
# Violation time # 66,The distance violation happens at # 5 point
# The w is adjusted to [-286119, -229999, 22038]
# Redoing the normal perceptron
# 现在我们有 66 次违例
# 3883.75
# Violation time # 67,The violation happens at # 1 point
# The w is adjusted to [-293801, -237494, 22208]
# No violation happens
# 现在我们有 67 次违例
# 3883.75
# Violation time # 68,The distance violation happens at # 3 point
# The w is adjusted to [-303523, -229120, 13451]
# Redoing the normal perceptron
# 现在我们有 68 次违例
# 3883.75
# Violation time # 69,The violation happens at # 1 point
# The w is adjusted to [-311205, -236615, 13621]
# No violation happens
# 现在我们有 69 次违例
# 3883.75
# Violation time # 70,The distance violation happens at # 5 point
# The w is adjusted to [-306103, -240994, 20296]
# Redoing the normal perceptron
# 现在我们有 70 次违例
# 3883.75
# Violation time # 71,The violation happens at # 1 point
# The w is adjusted to [-313785, -248489, 20466]
# No violation happens
# 现在我们有 71 次违例
# 3883.75
# Violation time # 72,The distance violation happens at # 5 point
# The w is adjusted to [-308683, -252868, 27141]
# Redoing the normal perceptron
# 现在我们有 72 次违例
# 3883.75
# Violation time # 73,The violation happens at # 1 point
# The w is adjusted to [-316365, -260363, 27311]
# No violation happens
# 现在我们有 73 次违例
# 3883.75
# Violation time # 74,The distance violation happens at # 3 point
# The w is adjusted to [-326087, -251989, 18554]
# Redoing the normal perceptron
# 现在我们有 74 次违例
# 3883.75
# Violation time # 75,The violation happens at # 1 point
# The w is adjusted to [-333769, -259484, 18724]
# No violation happens
# 现在我们有 75 次违例
# 3883.75
# Violation time # 76,The distance violation happens at # 5 point
# The w is adjusted to [-328667, -263863, 25399]
# Redoing the normal perceptron
# 现在我们有 76 次违例
# 3883.75
# Violation time # 77,The violation happens at # 1 point
# The w is adjusted to [-336349, -271358, 25569]
# No violation happens
# 现在我们有 77 次违例
# 3883.75
# Violation time # 78,The distance violation happens at # 3 point
# The w is adjusted to [-346071, -262984, 16812]
# Redoing the normal perceptron
# 现在我们有 78 次违例
# 3883.75
# Violation time # 79,The violation happens at # 1 point
# The w is adjusted to [-353753, -270479, 16982]
# No violation happens
# 现在我们有 79 次违例
# 3883.75
# Violation time # 80,The distance violation happens at # 5 point
# The w is adjusted to [-348651, -274858, 23657]
# Redoing the normal perceptron
# 现在我们有 80 次违例
# 3883.75
# Violation time # 81,The violation happens at # 1 point
# The w is adjusted to [-356333, -282353, 23827]
# No violation happens
# 现在我们有 81 次违例
# 3883.75
# Violation time # 82,The distance violation happens at # 5 point
# The w is adjusted to [-351231, -286732, 30502]
# Redoing the normal perceptron
# 现在我们有 82 次违例
# 3883.75
# Violation time # 83,The violation happens at # 1 point
# The w is adjusted to [-358913, -294227, 30672]
# No violation happens
# 现在我们有 83 次违例
# 3883.75
# Violation time # 84,The distance violation happens at # 3 point
# The w is adjusted to [-368635, -285853, 21915]
# Redoing the normal perceptron
# 现在我们有 84 次违例
# 3883.75
# Violation time # 85,The violation happens at # 1 point
# The w is adjusted to [-376317, -293348, 22085]
# No violation happens
# 现在我们有 85 次违例
# 3883.75
# Violation time # 86,The distance violation happens at # 5 point
# The w is adjusted to [-371215, -297727, 28760]
# Redoing the normal perceptron
# 现在我们有 86 次违例
# 3883.75
# Violation time # 87,The violation happens at # 1 point
# The w is adjusted to [-378897, -305222, 28930]
# No violation happens
# 现在我们有 87 次违例
# 3883.75
# Violation time # 88,The distance violation happens at # 3 point
# The w is adjusted to [-388619, -296848, 20173]
# Redoing the normal perceptron
# 现在我们有 88 次违例
# 3883.75
# Violation time # 89,The violation happens at # 1 point
# The w is adjusted to [-396301, -304343, 20343]
# No violation happens
# 现在我们有 89 次违例
# 3883.75
# Violation time # 90,The distance violation happens at # 5 point
# The w is adjusted to [-391199, -308722, 27018]
# Redoing the normal perceptron
# 现在我们有 90 次违例
# 3883.75
# Violation time # 91,The violation happens at # 1 point
# The w is adjusted to [-398881, -316217, 27188]
# No violation happens
# 现在我们有 91 次违例
# 3883.75
# Violation time # 92,The distance violation happens at # 5 point
# The w is adjusted to [-393779, -320596, 33863]
# Redoing the normal perceptron
# 现在我们有 92 次违例
# 3883.75
# Violation time # 93,The violation happens at # 1 point
# The w is adjusted to [-401461, -328091, 34033]
# No violation happens
# 现在我们有 93 次违例
# 3883.75
# Violation time # 94,The distance violation happens at # 3 point
# The w is adjusted to [-411183, -319717, 25276]
# Redoing the normal perceptron
# 现在我们有 94 次违例
# 3883.75
# Violation time # 95,The violation happens at # 1 point
# The w is adjusted to [-418865, -327212, 25446]
# No violation happens
# 现在我们有 95 次违例
# 3883.75
# Violation time # 96,The distance violation happens at # 5 point
# The w is adjusted to [-413763, -331591, 32121]
# Redoing the normal perceptron
# 现在我们有 96 次违例
# 3883.75
# Violation time # 97,The violation happens at # 1 point
# The w is adjusted to [-421445, -339086, 32291]
# No violation happens
# 现在我们有 97 次违例
# 3883.75
# Violation time # 98,The distance violation happens at # 3 point
# The w is adjusted to [-431167, -330712, 23534]
# Redoing the normal perceptron
# 现在我们有 98 次违例
# 3883.75
# Violation time # 99,The violation happens at # 1 point
# The w is adjusted to [-438849, -338207, 23704]
# No violation happens
# 现在我们有 99 次违例
# 3883.75
# Violation time # 100,The distance violation happens at # 5 point
# The w is adjusted to [-433747, -342586, 30379]
# Redoing the normal perceptron
# 现在我们有 100 次违例
# 3883.75
# Violation time # 101,The violation happens at # 1 point
# The w is adjusted to [-441429, -350081, 30549]
# No violation happens
# 现在我们有 101 次违例
# 3883.75
# Violation time # 102,The distance violation happens at # 3 point
# The w is adjusted to [-451151, -341707, 21792]
# Redoing the normal perceptron
# 现在我们有 102 次违例
# 3883.75
# Violation time # 103,The violation happens at # 1 point
# The w is adjusted to [-458833, -349202, 21962]
# No violation happens
# 现在我们有 103 次违例
# 3883.75
# Violation time # 104,The distance violation happens at # 5 point
# The w is adjusted to [-453731, -353581, 28637]
# Redoing the normal perceptron
# 现在我们有 104 次违例
# 3883.75
# Violation time # 105,The violation happens at # 1 point
# The w is adjusted to [-461413, -361076, 28807]
# No violation happens
# 现在我们有 105 次违例
# 3883.75
# Violation time # 106,The distance violation happens at # 5 point
# The w is adjusted to [-456311, -365455, 35482]
# Redoing the normal perceptron
# 现在我们有 106 次违例
# 3883.75
# Violation time # 107,The violation happens at # 1 point
# The w is adjusted to [-463993, -372950, 35652]
# No violation happens
# 现在我们有 107 次违例
# 3883.75
# Violation time # 108,The distance violation happens at # 3 point
# The w is adjusted to [-473715, -364576, 26895]
# Redoing the normal perceptron
# 现在我们有 108 次违例
# 3883.75
# Violation time # 109,The violation happens at # 1 point
# The w is adjusted to [-481397, -372071, 27065]
# No violation happens
# 现在我们有 109 次违例
# 3883.75
# Violation time # 110,The distance violation happens at # 5 point
# The w is adjusted to [-476295, -376450, 33740]
# Redoing the normal perceptron
# 现在我们有 110 次违例
# 3883.75
# Violation time # 111,The violation happens at # 1 point
# The w is adjusted to [-483977, -383945, 33910]
# No violation happens
# 现在我们有 111 次违例
# 3883.75
# Violation time # 112,The distance violation happens at # 3 point
# The w is adjusted to [-493699, -375571, 25153]
# Redoing the normal perceptron
# 现在我们有 112 次违例
# 3883.75
# Violation time # 113,The violation happens at # 1 point
# The w is adjusted to [-501381, -383066, 25323]
# No violation happens
# 现在我们有 113 次违例
# 3883.75
# Violation time # 114,The distance violation happens at # 5 point
# The w is adjusted to [-496279, -387445, 31998]
# Redoing the normal perceptron
# 现在我们有 114 次违例
# 3883.75
# Violation time # 115,The violation happens at # 1 point
# The w is adjusted to [-503961, -394940, 32168]
# No violation happens
# 现在我们有 115 次违例
# 3883.75
# Violation time # 116,The distance violation happens at # 5 point
# The w is adjusted to [-498859, -399319, 38843]
# Redoing the normal perceptron
# 现在我们有 116 次违例
# 3883.75
# Violation time # 117,The violation happens at # 1 point
# The w is adjusted to [-506541, -406814, 39013]
# No violation happens
# 现在我们有 117 次违例
# 3883.75
# Violation time # 118,The distance violation happens at # 3 point
# The w is adjusted to [-516263, -398440, 30256]
# Redoing the normal perceptron
# 现在我们有 118 次违例
# 3883.75
# Violation time # 119,The violation happens at # 1 point
# The w is adjusted to [-523945, -405935, 30426]
# No violation happens
# 现在我们有 119 次违例
# 3883.75
# Violation time # 120,The distance violation happens at # 5 point
# The w is adjusted to [-518843, -410314, 37101]
# Redoing the normal perceptron
# 现在我们有 120 次违例
# 3883.75
# Violation time # 121,The violation happens at # 1 point
# The w is adjusted to [-526525, -417809, 37271]
# No violation happens
# 现在我们有 121 次违例
# 3883.75
# Violation time # 122,The distance violation happens at # 3 point
# The w is adjusted to [-536247, -409435, 28514]
# Redoing the normal perceptron
# 现在我们有 122 次违例
# 3883.75
# Violation time # 123,The violation happens at # 1 point
# The w is adjusted to [-543929, -416930, 28684]
# No violation happens
# 现在我们有 123 次违例
# 3883.75
# Violation time # 124,The distance violation happens at # 5 point
# The w is adjusted to [-538827, -421309, 35359]
# Redoing the normal perceptron
# 现在我们有 124 次违例
# 3883.75
# Violation time # 125,The violation happens at # 1 point
# The w is adjusted to [-546509, -428804, 35529]
# No violation happens
# 现在我们有 125 次违例
# 3883.75
# Violation time # 126,The distance violation happens at # 5 point
# The w is adjusted to [-541407, -433183, 42204]
# Redoing the normal perceptron
# 现在我们有 126 次违例
# 3883.75
# Violation time # 127,The violation happens at # 1 point
# The w is adjusted to [-549089, -440678, 42374]
# No violation happens
# 现在我们有 127 次违例
# 3883.75
# Violation time # 128,The distance violation happens at # 3 point
# The w is adjusted to [-558811, -432304, 33617]
# Redoing the normal perceptron
# 现在我们有 128 次违例
# 3883.75
# Violation time # 129,The violation happens at # 1 point
# The w is adjusted to [-566493, -439799, 33787]
# No violation happens
# 现在我们有 129 次违例
# 3883.75
# Violation time # 130,The distance violation happens at # 5 point
# The w is adjusted to [-561391, -444178, 40462]
# Redoing the normal perceptron
# 现在我们有 130 次违例
# 3883.75
# Violation time # 131,The violation happens at # 1 point
# The w is adjusted to [-569073, -451673, 40632]
# No violation happens
# 现在我们有 131 次违例
# 3883.75
# Violation time # 132,The distance violation happens at # 3 point
# The w is adjusted to [-578795, -443299, 31875]
# Redoing the normal perceptron
# 现在我们有 132 次违例
# 3883.75
# Violation time # 133,The violation happens at # 1 point
# The w is adjusted to [-586477, -450794, 32045]
# No violation happens
# 现在我们有 133 次违例
# 3883.75
# Violation time # 134,The distance violation happens at # 5 point
# The w is adjusted to [-581375, -455173, 38720]
# Redoing the normal perceptron
# 现在我们有 134 次违例
# 3883.75
# Violation time # 135,The violation happens at # 1 point
# The w is adjusted to [-589057, -462668, 38890]
# No violation happens
# 现在我们有 135 次违例
# 3883.75
# Violation time # 136,The distance violation happens at # 5 point
# The w is adjusted to [-583955, -467047, 45565]
# Redoing the normal perceptron
# 现在我们有 136 次违例
# 3883.75
# Violation time # 137,The violation happens at # 1 point
# The w is adjusted to [-591637, -474542, 45735]
# No violation happens
# 现在我们有 137 次违例
# 3883.75
# Violation time # 138,The distance violation happens at # 3 point
# The w is adjusted to [-601359, -466168, 36978]
# Redoing the normal perceptron
# 现在我们有 138 次违例
# 3883.75
# Violation time # 139,The violation happens at # 1 point
# The w is adjusted to [-609041, -473663, 37148]
# No violation happens
# 现在我们有 139 次违例
# 3883.75
# Violation time # 140,The distance violation happens at # 5 point
# The w is adjusted to [-603939, -478042, 43823]
# Redoing the normal perceptron
# 现在我们有 140 次违例
# 3883.75
# Violation time # 141,The violation happens at # 1 point
# The w is adjusted to [-611621, -485537, 43993]
# No violation happens
# 现在我们有 141 次违例
# 3883.75
# Violation time # 142,The distance violation happens at # 3 point
# The w is adjusted to [-621343, -477163, 35236]
# Redoing the normal perceptron
# 现在我们有 142 次违例
# 3883.75
# Violation time # 143,The violation happens at # 1 point
# The w is adjusted to [-629025, -484658, 35406]
# No violation happens
# 现在我们有 143 次违例
# 3883.75
# Violation time # 144,The distance violation happens at # 5 point
# The w is adjusted to [-623923, -489037, 42081]
# Redoing the normal perceptron
# 现在我们有 144 次违例
# 3883.75
# Violation time # 145,The violation happens at # 1 point
# The w is adjusted to [-631605, -496532, 42251]
# No violation happens
# 现在我们有 145 次违例
# 3883.75
# Violation time # 146,The distance violation happens at # 5 point
# The w is adjusted to [-626503, -500911, 48926]
# Redoing the normal perceptron
# 现在我们有 146 次违例
# 3883.75
# Violation time # 147,The violation happens at # 1 point
# The w is adjusted to [-634185, -508406, 49096]
# No violation happens
# 现在我们有 147 次违例
# 3883.75
# Violation time # 148,The distance violation happens at # 3 point
# The w is adjusted to [-643907, -500032, 40339]
# Redoing the normal perceptron
# 现在我们有 148 次违例
# 3883.75
# Violation time # 149,The violation happens at # 1 point
# The w is adjusted to [-651589, -507527, 40509]
# No violation happens
# 现在我们有 149 次违例
# 3883.75
# Violation time # 150,The distance violation happens at # 5 point
# The w is adjusted to [-646487, -511906, 47184]
# Redoing the normal perceptron
# 现在我们有 150 次违例
# 3883.75
# Violation time # 151,The violation happens at # 1 point
# The w is adjusted to [-654169, -519401, 47354]
# No violation happens
# 现在我们有 151 次违例
# 3883.75
# Violation time # 152,The distance violation happens at # 3 point
# The w is adjusted to [-663891, -511027, 38597]
# Redoing the normal perceptron
# 现在我们有 152 次违例
# 3883.75
# Violation time # 153,The violation happens at # 1 point
# The w is adjusted to [-671573, -518522, 38767]
# No violation happens
# 现在我们有 153 次违例
# 3883.75
# Violation time # 154,The distance violation happens at # 5 point
# The w is adjusted to [-666471, -522901, 45442]
# Redoing the normal perceptron
# 现在我们有 154 次违例
# 3883.75
# Violation time # 155,The violation happens at # 1 point
# The w is adjusted to [-674153, -530396, 45612]
# No violation happens
# 现在我们有 155 次违例
# 3883.75
# Violation time # 156,The distance violation happens at # 5 point
# The w is adjusted to [-669051, -534775, 52287]
# Redoing the normal perceptron
# 现在我们有 156 次违例
# 3883.75
# Violation time # 157,The violation happens at # 1 point
# The w is adjusted to [-676733, -542270, 52457]
# No violation happens
# 现在我们有 157 次违例
# 3883.75
# Violation time # 158,The distance violation happens at # 3 point
# The w is adjusted to [-686455, -533896, 43700]
# Redoing the normal perceptron
# 现在我们有 158 次违例
# 3883.75
# Violation time # 159,The violation happens at # 1 point
# The w is adjusted to [-694137, -541391, 43870]
# No violation happens
# 现在我们有 159 次违例
# 3883.75
# Violation time # 160,The distance violation happens at # 5 point
# The w is adjusted to [-689035, -545770, 50545]
# Redoing the normal perceptron
# 现在我们有 160 次违例
# 3883.75
# Violation time # 161,The violation happens at # 1 point
# The w is adjusted to [-696717, -553265, 50715]
# No violation happens
# 现在我们有 161 次违例
# 3883.75
# Violation time # 162,The distance violation happens at # 3 point
# The w is adjusted to [-706439, -544891, 41958]
# Redoing the normal perceptron
# 现在我们有 162 次违例
# 3883.75
# Violation time # 163,The violation happens at # 1 point
# The w is adjusted to [-714121, -552386, 42128]
# No violation happens
# 现在我们有 163 次违例
# 3883.75
# Violation time # 164,The distance violation happens at # 5 point
# The w is adjusted to [-709019, -556765, 48803]
# Redoing the normal perceptron
# 现在我们有 164 次违例
# 3883.75
# Violation time # 165,The violation happens at # 1 point
# The w is adjusted to [-716701, -564260, 48973]
# No violation happens
# 现在我们有 165 次违例
# 3883.75
# Violation time # 166,The distance violation happens at # 5 point
# The w is adjusted to [-711599, -568639, 55648]
# Redoing the normal perceptron
# 现在我们有 166 次违例
# 3883.75
# Violation time # 167,The violation happens at # 1 point
# The w is adjusted to [-719281, -576134, 55818]
# No violation happens
# 现在我们有 167 次违例
# 3883.75
# Violation time # 168,The distance violation happens at # 3 point
# The w is adjusted to [-729003, -567760, 47061]
# Redoing the normal perceptron
# 现在我们有 168 次违例
# 3883.75
# Violation time # 169,The violation happens at # 1 point
# The w is adjusted to [-736685, -575255, 47231]
# No violation happens
# 现在我们有 169 次违例
# 3883.75
# Violation time # 170,The distance violation happens at # 5 point
# The w is adjusted to [-731583, -579634, 53906]
# Redoing the normal perceptron
# 现在我们有 170 次违例
# 3883.75
# Violation time # 171,The violation happens at # 1 point
# The w is adjusted to [-739265, -587129, 54076]
# No violation happens
# 现在我们有 171 次违例
# 3883.75
# Violation time # 172,The distance violation happens at # 3 point
# The w is adjusted to [-748987, -578755, 45319]
# Redoing the normal perceptron
# 现在我们有 172 次违例
# 3883.75
# Violation time # 173,The violation happens at # 1 point
# The w is adjusted to [-756669, -586250, 45489]
# No violation happens
# 现在我们有 173 次违例
# 3883.75
# Violation time # 174,The distance violation happens at # 5 point
# The w is adjusted to [-751567, -590629, 52164]
# Redoing the normal perceptron
# 现在我们有 174 次违例
# 3883.75
# Violation time # 175,The violation happens at # 1 point
# The w is adjusted to [-759249, -598124, 52334]
# No violation happens
# 现在我们有 175 次违例
# 3883.75
# Violation time # 176,The distance violation happens at # 5 point
# The w is adjusted to [-754147, -602503, 59009]
# Redoing the normal perceptron
# 现在我们有 176 次违例
# 3883.75
# Violation time # 177,The violation happens at # 1 point
# The w is adjusted to [-761829, -609998, 59179]
# No violation happens
# 现在我们有 177 次违例
# 3883.75
# Violation time # 178,The distance violation happens at # 3 point
# The w is adjusted to [-771551, -601624, 50422]
# Redoing the normal perceptron
# 现在我们有 178 次违例
# 3883.75
# Violation time # 179,The violation happens at # 1 point
# The w is adjusted to [-779233, -609119, 50592]
# No violation happens
# 现在我们有 179 次违例
# 3883.75
# Violation time # 180,The distance violation happens at # 5 point
# The w is adjusted to [-774131, -613498, 57267]
# Redoing the normal perceptron
# 现在我们有 180 次违例
# 3883.75
# Violation time # 181,The violation happens at # 1 point
# The w is adjusted to [-781813, -620993, 57437]
# No violation happens
# 现在我们有 181 次违例
# 3883.75
# Violation time # 182,The distance violation happens at # 3 point
# The w is adjusted to [-791535, -612619, 48680]
# Redoing the normal perceptron
# 现在我们有 182 次违例
# 3883.75
# Violation time # 183,The violation happens at # 1 point
# The w is adjusted to [-799217, -620114, 48850]
# No violation happens
# 现在我们有 183 次违例
# 3883.75
# Violation time # 184,The distance violation happens at # 5 point
# The w is adjusted to [-794115, -624493, 55525]
# Redoing the normal perceptron
# 现在我们有 184 次违例
# 3883.75
# Violation time # 185,The violation happens at # 1 point
# The w is adjusted to [-801797, -631988, 55695]
# No violation happens
# 现在我们有 185 次违例
# 3883.75
# Violation time # 186,The distance violation happens at # 5 point
# The w is adjusted to [-796695, -636367, 62370]
# Redoing the normal perceptron
# 现在我们有 186 次违例
# 3883.75
# Violation time # 187,The violation happens at # 1 point
# The w is adjusted to [-804377, -643862, 62540]
# No violation happens
# 现在我们有 187 次违例
# 3883.75
# Violation time # 188,The distance violation happens at # 3 point
# The w is adjusted to [-814099, -635488, 53783]
# Redoing the normal perceptron
# 现在我们有 188 次违例
# 3883.75
# Violation time # 189,The violation happens at # 1 point
# The w is adjusted to [-821781, -642983, 53953]
# No violation happens
# 现在我们有 189 次违例
# 3883.75
# Violation time # 190,The distance violation happens at # 5 point
# The w is adjusted to [-816679, -647362, 60628]
# Redoing the normal perceptron
# 现在我们有 190 次违例
# 3883.75
# Violation time # 191,The violation happens at # 1 point
# The w is adjusted to [-824361, -654857, 60798]
# No violation happens
# 现在我们有 191 次违例
# 3883.75
# Violation time # 192,The distance violation happens at # 3 point
# The w is adjusted to [-834083, -646483, 52041]
# Redoing the normal perceptron
# 现在我们有 192 次违例
# Violation次数超出限制，r_guess减小一倍
# 1941.875
# Violation time # 1,The violation happens at # 1 point
# The w is adjusted to [-7682, -7495, 170]
# No violation happens
# 现在我们有 1 次违例
# 1941.875
# Violation time # 2,The distance violation happens at # 5 point
# The w is adjusted to [-2580, -11874, 6845]
# Redoing the normal perceptron
# 现在我们有 2 次违例
# 1941.875
# Violation time # 3,The violation happens at # 1 point
# The w is adjusted to [-10262, -19369, 7015]
# No violation happens
# 现在我们有 3 次违例
# 1941.875
# Violation time # 4,The distance violation happens at # 4 point
# The w is adjusted to [-909, -22238, 15702]
# Redoing the normal perceptron
# 现在我们有 4 次违例
# 1941.875
# Violation time # 5,The violation happens at # 1 point
# The w is adjusted to [-8591, -29733, 15872]
# No violation happens
# 现在我们有 5 次违例
# 1941.875
# Violation time # 6,The distance violation happens at # 14 point
# The w is adjusted to [-17461, -30260, 11903]
# Redoing the normal perceptron
# 现在我们有 6 次违例
# 1941.875
# Violation time # 7,The violation happens at # 1 point
# The w is adjusted to [-25143, -37755, 12073]
# No violation happens
# 现在我们有 7 次违例
# 1941.875
# Violation time # 8,The distance violation happens at # 4 point
# The w is adjusted to [-15790, -40624, 20760]
# Redoing the normal perceptron
# 现在我们有 8 次违例
# 1941.875
# Violation time # 9,The violation happens at # 1 point
# The w is adjusted to [-23472, -48119, 20930]
# No violation happens
# 现在我们有 9 次违例
# 1941.875
# Violation time # 10,The distance violation happens at # 6 point
# The w is adjusted to [-32245, -45733, 17497]
# Redoing the normal perceptron
# 现在我们有 10 次违例
# 1941.875
# Violation time # 11,The violation happens at # 1 point
# The w is adjusted to [-39927, -53228, 17667]
# No violation happens
# 现在我们有 11 次违例
# 1941.875
# Violation time # 12,The distance violation happens at # 8 point
# The w is adjusted to [-37145, -53526, 24186]
# Redoing the normal perceptron
# 现在我们有 12 次违例
# 1941.875
# Violation time # 13,The violation happens at # 1 point
# The w is adjusted to [-44827, -61021, 24356]
# No violation happens
# 现在我们有 13 次违例
# 1941.875
# Violation time # 14,The distance violation happens at # 4 point
# The w is adjusted to [-35474, -63890, 33043]
# Redoing the normal perceptron
# 现在我们有 14 次违例
# 1941.875
# Violation time # 15,The violation happens at # 1 point
# The w is adjusted to [-43156, -71385, 33213]
# No violation happens
# 现在我们有 15 次违例
# 1941.875
# No distance violation happens
# 现在我们有 15 次违例
# 1941.875
# The final w is [-43156, -71385, 33213]
# We guarantee the margin to be at least 970.9375
# Total violation time is 15

# %%
a = True
while(a == True):
    a = False
    print('test')
# Out:
# test
